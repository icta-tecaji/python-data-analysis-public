# %% [markdown]
# # Prikazovanje podatkov - osnonvo

# %% [markdown]
# ## Representation Of Data

# %% [markdown]
# ## Introduction To The Data

# %%
import pandas as pd

# %%
unrate = pd.read_csv("data/unrate.csv")

# %%
print(unrate.info())
unrate.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    824 non-null    object
#  1   VALUE   824 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.0+ KB
# None
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5

# %%
unrate["DATE"] = pd.to_datetime(unrate["DATE"])

# %%
unrate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 824 entries, 0 to 823
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DATE    824 non-null    datetime64[ns]
#  1   VALUE   824 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 13.0 KB

# %%
unrate.head(12)
# Out:
#          DATE  VALUE
# 0  1948-01-01    3.4
# 1  1948-02-01    3.8
# 2  1948-03-01    4.0
# 3  1948-04-01    3.9
# 4  1948-05-01    3.5
# 5  1948-06-01    3.6
# 6  1948-07-01    3.6
# 7  1948-08-01    3.9
# 8  1948-09-01    3.8
# 9  1948-10-01    3.7
# 10 1948-11-01    3.8
# 11 1948-12-01    4.0

# %% [markdown]
# ![Foo](https://img.search.brave.com/bPR27Yi3DQ44eAMF-Nxyw5BFlKckXllJId8Pp7UpvNE/fit/680/493/ce/1/aHR0cDovL2kyLmt5/bS1jZG4uY29tL3Bo/b3Rvcy9pbWFnZXMv/bmV3c2ZlZWQvMDAx/LzE5NS8yNDIvZWU5/LnBuZw)

# %% [markdown]
# ## Introduction to matplotlib

# %% [markdown]
# pip install matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot()
plt.show()

# %% [markdown]
# ## Axis Ticks

# %% [markdown]
# <p><img alt="Axis Ticks" src="images/axis+ticks.png"></p>

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve["DATE"], first_twelve["VALUE"])
plt.show()

# %% [markdown]
# ### Fixing Axis Ticks

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve["DATE"], first_twelve["VALUE"])
plt.xticks(
    ticks = first_twelve["DATE"],
    labels = first_twelve["DATE"],
    rotation = 90)
plt.show()

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve["DATE"], first_twelve["VALUE"])
plt.xticks(
    ticks = first_twelve["DATE"],
    labels = [dt.strftime("%Y-%m") for dt in first_twelve["DATE"]],
    rotation = 90)
plt.show()

# %% [markdown]
# ### Adding Axis Labels And A Title

# %%
first_twelve = unrate[0:12]
plt.plot(first_twelve["DATE"], first_twelve["VALUE"])
plt.xticks(
    ticks = first_twelve["DATE"],
    labels = [dt.strftime("%Y-%m") for dt in first_twelve["DATE"]],
    rotation = 90)
plt.xlabel("Month")
plt.ylabel("Unemployment Rate")
plt.title("Monthly Unemployment trends, 1948")
plt.show()

# %% [markdown]
# ## Matplotlib Classes

# %%
fig = plt.figure()

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

plt.show()

# %% [markdown]
# ## Grid Positioning

# %% [markdown]
# <p><img alt="Subplot Grid" src="images/subplot_grid.png"></p>

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax4 = fig.add_subplot(2, 2, 4)

plt.show()

# %% [markdown]
# ## Adding Data

# %%
first_twelve = unrate[:12]
second_twelve = unrate[12:24]

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(first_twelve["DATE"], first_twelve["VALUE"])
ax2.plot(second_twelve["DATE"], second_twelve["VALUE"])

ax1.set_title("Monthly unemployment rate, 1948")
ax2.set_title("Monthly unemployment rate, 1949")

plt.show()

# %% [markdown]
# ## Formatting And Spacing

# %% [markdown]
# <p><img alt="Two Plots" src="images/plotting_area_stays_same.png"></p>

# %%
first_twelve = unrate[:12]
second_twelve = unrate[12:24]

fig = plt.figure(figsize=(10, 8))
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(first_twelve["DATE"], first_twelve["VALUE"])
ax2.plot(second_twelve["DATE"], second_twelve["VALUE"])

ax1.set_title("Monthly unemployment rate, 1948")
ax2.set_title("Monthly unemployment rate, 1949")

plt.show()

# %% [markdown]
# ## Comparing Across More Years

# %%
fig = plt.figure(figsize=(12, 12))

for i in range(5):
    ax = fig.add_subplot(5, 1, i+1)
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index : end_index]
    ax.plot(subset["DATE"], subset["VALUE"])
    
plt.show()

# %% [markdown]
# ## Overlaying Line Charts

# %%
unrate["MONTH"] = unrate["DATE"].dt.month

# %%
unrate.head(14)
# Out:
#          DATE  VALUE  MONTH
# 0  1948-01-01    3.4      1
# 1  1948-02-01    3.8      2
# 2  1948-03-01    4.0      3
# 3  1948-04-01    3.9      4
# 4  1948-05-01    3.5      5
# 5  1948-06-01    3.6      6
# 6  1948-07-01    3.6      7
# 7  1948-08-01    3.9      8
# 8  1948-09-01    3.8      9
# 9  1948-10-01    3.7     10
# 10 1948-11-01    3.8     11
# 11 1948-12-01    4.0     12
# 12 1949-01-01    4.3      1
# 13 1949-02-01    4.7      2

# %%
fig = plt.figure(figsize=(4, 4))

unrate_1948 = unrate[:12]
unrate_1949 = unrate[12:24]

ax = fig.add_subplot(1, 1, 1)

ax.plot(unrate_1948["MONTH"], unrate_1948["VALUE"], color="red")
ax.plot(unrate_1949["MONTH"], unrate_1949["VALUE"], c="green")

plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

colors = ["red", "blue", "green", "orange", "black"]

for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index : end_index]
    ax.plot(subset["MONTH"], subset["VALUE"], c=colors[i])
    
plt.show()

# %% [markdown]
# ## Adding A Legend

# %% [markdown]
# <p><img alt="Legend" src="https://s3.amazonaws.com/dq-content/legend.png"></p>

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

colors = ["red", "blue", "green", "orange", "black"]

for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index : end_index]
    ax.plot(subset["MONTH"], subset["VALUE"], c=colors[i], label=str(1948+i))

ax.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

colors = ["red", "blue", "green", "orange", "black"]

for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index : end_index]
    ax.plot(subset["MONTH"], subset["VALUE"], c=colors[i], label=str(1948+i))

ax.legend(loc="upper left")
ax.set_title("Monthly unemployment trends 1948 - 1952")
ax.set_xlabel("Months")
ax.set_ylabel("Unemployment rate, %")
plt.show()

# %% [markdown]
# ## Gridlines

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(1, 1, 1)

colors = ["red", "blue", "green", "orange", "black"]

for i in range(5):
    start_index = i*12
    end_index = (i+1)*12
    subset = unrate[start_index : end_index]
    ax.plot(subset["MONTH"], subset["VALUE"], c=colors[i], label=str(1948+i))

ax.legend(loc="upper left")
ax.set_title("Monthly unemployment trends 1948 - 1952")
ax.set_xlabel("Months")
ax.set_ylabel("Unemployment rate, %")

ax.minorticks_on()
ax.grid(which="both", axis="y")
plt.show()

# %% [markdown]
# # Bar plots

# %% [markdown]
# ## Introduction to the data

# %%
reviews = pd.read_csv("data/fandango_scores.csv")

# %%
cols = ["FILM", "RT_user_norm", "Metacritic_user_nom", "IMDB_norm", "Fandango_Ratingvalue", "Fandango_Stars"]

# %%
norm_reviews = reviews[cols]

# %%
norm_reviews.head(10)
# Out:
#                              FILM  RT_user_norm  Metacritic_user_nom  \
# 0  Avengers: Age of Ultron (2015)          4.30                 3.55
# 1               Cinderella (2015)          4.00                 3.75
# 2                  Ant-Man (2015)          4.50                 4.05
# 3          Do You Believe? (2015)          4.20                 2.35
# 4   Hot Tub Time Machine 2 (2015)          1.40                 1.70
# 5        The Water Diviner (2015)          3.10                 3.40
# 6           Irrational Man (2015)          2.65                 3.80
# 7                 Top Five (2014)          3.20                 3.40
# 8    Shaun the Sheep Movie (2015)          4.10                 4.40
# 9             Love & Mercy (2015)          4.35                 4.25
#
#    IMDB_norm  Fandango_Ratingvalue  Fandango_Stars
# 0       3.90                   4.5             5.0
# 1       3.55                   4.5             5.0
# 2       3.90                   4.5             5.0
# ...

# %% [markdown]
# ## Bar Plots

# %% [markdown]
# <p><img alt="Vertical Bar Plot" src="images/vertical_bar_plot.png"></p>

# %% [markdown]
# ### Creating Bars

# %% [markdown]
# <p><img alt="Matplotlib Barplot Positioning" src="images/matplotlib_barplot_positioning.png"></p>

# %%
review_cols = ["RT_user_norm", "Metacritic_user_nom", "IMDB_norm", "Fandango_Ratingvalue", "Fandango_Stars"]

movie = norm_reviews.loc[0, :]
print(movie)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar([1,2,3,4,5], movie[review_cols], width=-0.3, align="edge")

plt.show()
# Out:
# FILM                    Avengers: Age of Ultron (2015)
# RT_user_norm                                       4.3
# Metacritic_user_nom                               3.55
# IMDB_norm                                          3.9
# Fandango_Ratingvalue                               4.5
# Fandango_Stars                                     5.0
# Name: 0, dtype: object

# %% [markdown]
# ### Aligning Axis Ticks And Labels

# %%
review_cols = ["RT_user_norm", "Metacritic_user_nom", "IMDB_norm", "Fandango_Ratingvalue", "Fandango_Stars"]

movie = norm_reviews.loc[0, :]
print(movie)

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.bar([1,2,3,4,5], movie[review_cols], width=-0.3, align="edge")

ax.set_xticks([1,2,3,4,5])
ax.set_xticklabels(review_cols, rotation=90)

ax.set_xlabel("Rating Source")
ax.set_ylabel("Average score")
ax.set_title("Average user rating for Avengers: Age of Ultron")
plt.show()
# Out:
# FILM                    Avengers: Age of Ultron (2015)
# RT_user_norm                                       4.3
# Metacritic_user_nom                               3.55
# IMDB_norm                                          3.9
# Fandango_Ratingvalue                               4.5
# Fandango_Stars                                     5.0
# Name: 0, dtype: object

# %% [markdown]
# ### Horizontal Bar Plot

# %% [markdown]
# ## Scatter plot

# %% [markdown]
# <p><img alt="Imgur" src="images/scatter_plot_intro.png"></p>

# %% [markdown]
# ### Switching axes

# %% [markdown]
# ### Benchmarking correlation

# %% [markdown]
# ## Histogram

# %% [markdown]
# ### Frequency Distribution

# %% [markdown]
# ### Binning

# %% [markdown]
# <p><img alt="Binning Introduction" src="images/histogram_binning.png"></p>

# %% [markdown]
# ### Histogram In Matplotlib

# %% [markdown]
# ### Comparing histograms

# %% [markdown]
# ### Quartiles

# %% [markdown]
# ## Box Plot

# %% [markdown]
# <p><img alt="Boxplot" src="images/boxplot_intro.png"></p>

# %% [markdown]
# ### Multiple Box Plots
