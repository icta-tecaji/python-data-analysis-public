# %% [markdown]
# # Prikazovanje podatkov - osnonvo

# %% [markdown]
# ## Representation Of Data

# %% [markdown]
# ## Introduction To The Data

# %% [markdown]
# [Dataset](https://www.kaggle.com/datasets/rajanand/rainfall-in-india?resource=download)
#
# Mesečne vrednosti padavin v **mm** za pokrajne in okrožja:
# * `STATE_UT_NAME` - pokrajina
# * `DISTRICT` - okrožje
# * `JAN` - padavine v januarju
# * `FEB` - padavine v februarju
# * `MAR` - padavine v marcu
# * `APR` - padavine v aprilu
# * `MAY` - padavine v maju
# * `JUN` - padavine v juniju
# * `JUL` - padavine v juliju
# * `AUG` - padavine v augustu
# * `SEP` - padavine v septembru
# * `OCT` - padavine v oktobru
# * `NOV` - padavine v novembru
# * `DEC` - padavine v decembru
# * `ANNUAL` - letne padavine
# * `Jan-Feb` - padavine v obdobju jan-feb
# * `Mar-May` - padavine v obdobju mar-maj
# * `Jun-Sep` - padavine v obdobju junij-sept
# * `Oct-Dec` - padavine v obdobju okt-dec

# %%
import pandas as pd

# %%
data = pd.read_csv("./data/district wise rainfall normal.csv")
print(data.info())
data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 19 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   STATE_UT_NAME  641 non-null    object
#  1   DISTRICT       641 non-null    object
#  2   JAN            641 non-null    float64
#  3   FEB            641 non-null    float64
#  4   MAR            641 non-null    float64
#  5   APR            641 non-null    float64
#  6   MAY            641 non-null    float64
#  7   JUN            641 non-null    float64
#  8   JUL            641 non-null    float64
#  9   AUG            641 non-null    float64
#  10  SEP            641 non-null    float64
#  11  OCT            641 non-null    float64
#  12  NOV            641 non-null    float64
#  13  DEC            641 non-null    float64
#  14  ANNUAL         641 non-null    float64
#  15  Jan-Feb        641 non-null    float64
#  16  Mar-May        641 non-null    float64
# ...

# %% [markdown]
# ----

# %%
data.iloc[0]
# Out:
# STATE_UT_NAME    ANDAMAN And NICOBAR ISLANDS
# DISTRICT                             NICOBAR
# JAN                                    107.3
# FEB                                     57.9
# MAR                                     65.2
# APR                                    117.0
# MAY                                    358.5
# JUN                                    295.5
# JUL                                    285.0
# AUG                                    271.9
# SEP                                    354.8
# OCT                                    326.0
# NOV                                    315.2
# DEC                                    250.9
# ANNUAL                                2805.2
# Jan-Feb                                165.2
# Mar-May                                540.7
# Jun-Sep                               1207.2
# Oct-Dec                                892.1
# Name: 0, dtype: object

# %% [markdown]
# ## Introduction to matplotlib

# %% [markdown]
# ```bash
# $ pip install matplotlib
# ```

# %% [markdown]
# ---

# %% [markdown]
# ```python
# import matplotlib.pyplot as plt
# ```

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
plt.plot()
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Axis Ticks

# %% [markdown]
# <p><img alt="Axis Ticks" src="images/axis+ticks.png"></p>

# %%
first_row = data.loc[0, "JAN":"DEC"].values
print(first_row)

plt.plot(first_row)
plt.show()
# Out:
# [107.3 57.9 65.2 117.0 358.5 295.5 285.0 271.9 354.8 326.0 315.2 250.9]

# %%
import numpy as np

x = np.linspace(4, 10, 50)
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Scatter plot

# %%
x = np.linspace(4, 10, 50)
y = np.sin(x)

plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Fixing Axis Ticks

# %% [markdown]
# * [xticks()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xticks.html#matplotlib.pyplot.xticks)
# * [yticks()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.yticks.html)

# %% [markdown]
# ```python
# matplotlib.pyplot.xticks(ticks=None, labels=None, **kwargs)
# ```

# %%
first_row = data.loc[0, "JAN":"DEC"].values
print(first_row)

plt.plot(first_row)
plt.show()
# Out:
# [107.3 57.9 65.2 117.0 358.5 295.5 285.0 271.9 354.8 326.0 315.2 250.9]

# %%
plt.plot(first_row)
plt.xticks(ticks=[1, 2, 5.5])
plt.show()

# %%
plt.plot(first_row)
plt.xticks(ticks=[1,2,5.5],
          labels=["one", "two", "five point five"])
plt.show()

# %%
plt.plot(first_row)
plt.xticks(ticks = range(12),
          labels = ["Januar", "Februar", "Marec", "April", "Maj", "Junij", "Julij", "Avgust", "September", "Oktober", "Noveber", "December"])

plt.show()

# %% [markdown]
# [Dokumentacija Text razreda](https://matplotlib.org/stable/api/text_api.html#matplotlib.text.Text)

# %%
plt.plot(first_row)
plt.xticks(ticks = range(12),
          labels = ["Januar", "Februar", "Marec", "April", "Maj", "Junij", "Julij", "Avgust", "September", "Oktober", "Noveber", "December"],
          rotation = 45)

plt.show()

# %%
first_row = data.loc[0, "JAN":"DEC"]
print(first_row)

plt.plot(first_row)
plt.show()
# Out:
# JAN    107.3
# FEB     57.9
# MAR     65.2
# APR    117.0
# MAY    358.5
# JUN    295.5
# JUL    285.0
# AUG    271.9
# SEP    354.8
# OCT    326.0
# NOV    315.2
# DEC    250.9
# Name: 0, dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Asix limits

# %% [markdown]
# * [plt.xlim](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlim.html)
# * [plt.ylim](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylim.html)

# %%
first_row = data.loc[0, "JAN":"DEC"]

plt.plot(first_row)

plt.xlim(-5, 20)
plt.ylim(0, 500)

plt.show()

# %% [markdown]
# ### Adding Axis Labels And A Title

# %% [markdown]
# * [xlabel()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html?highlight=xlabel#matplotlib.pyplot.xlabel) - vzeme string vrednost katero nastavi kot naslov x osi
# * [ylabel()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.ylabel.html?highlight=ylabel#matplotlib.pyplot.ylabel) - vzeme string vrednost katero nastavi kot naslov y osi
# * [title()](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html?highlight=title#matplotlib.pyplot.title) - vzeme string vrednost katero nastavi kot naslov grafa

# %%
first_row = data.loc[0, "JAN":"DEC"]

plt.plot(first_row)
plt.xlabel("Meseci")
plt.ylabel("Padavine [mm]")
plt.title("Padavine - NICOBAR")

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Matplotlib Classes

# %% [markdown]
# ```python
# pyplot.figure()
# ```

# %%
fig = plt.figure()

# %%
# %matplotlib notebook

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1, 2, 1)
ax2 = fig.add_subplot(1, 2, 2)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline

# %% [markdown]
# ---

# %% [markdown]
# ## Grid Positioning

# %% [markdown]
# <p><img alt="Subplot Grid" src="images/subplot_grid.png"></p>

# %%
fig = plt.figure()

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax4 = fig.add_subplot(2, 2, 4)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Adding Data

# %% [markdown]
#     x_values = [0.0, 0.5, 1.0]
#     y_values = [10, 20, 40]
#     ax1.plot(x_values, y_values)

# %%
first_row = data.iloc[0, 2:14]
second_row = data.iloc[1, 2:14]

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(first_row)
ax2.plot(second_row)

ax1.set_title("Padavine - NICOBAR")
ax2.set_title("Padavine - SOUTH ANDAMAN")

plt.show()

# %% [markdown]
# ## Formatting And Spacing

# %% [markdown]
# <img alt="Two Plots" src="images/plotting_area_stays_same.jpg">

# %%
first_row = data.iloc[0, 2:14]
second_row = data.iloc[1, 2:14]

fig = plt.figure(figsize=(10, 8), )
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(first_row)
ax2.plot(second_row)

ax1.set_title("Padavine - NICOBAR")
ax2.set_title("Padavine - SOUTH ANDAMAN")

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info not_clean">
# <b>Vaja:</b>
#
# Primerjajte sedaj med seboj prvih 5 vrstic.
# </div>

# %%
fig = plt.figure(figsize=(12, 20))

for i in range(5):
    ax = fig.add_subplot(5, 1, i+1)
    subset = data.iloc[i, 2:14]
    ax.plot(subset)
    ax.set_title(data.iloc[i, 1])
    
plt.show()

# %% [markdown]
# ## Overlaying Line Charts

# %%
subset = data.iloc[:5, 2:14]

fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(subset.iloc[0, :], c="#ff0000", linewidth=3, linestyle="--")
ax1.plot(subset.iloc[1, :], c="green", linewidth=10, linestyle="-.")
ax1.plot(subset.iloc[2, :])
ax1.plot(subset.iloc[3, :])
ax1.plot(subset.iloc[4, :])

plt.show()

# %% [markdown]
# ## Adding A Legend

# %%
subset = data.iloc[:5, 2:14]

fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(subset.iloc[0, :], label="NICOBAR")
ax1.plot(subset.iloc[1, :], label="SOUTH ANDAMAN")
ax1.plot(subset.iloc[2, :], label="N & M ANDAMAN")
ax1.plot(subset.iloc[3, :], label="LOHIT")
ax1.plot(subset.iloc[4, :], label="EAST SIANG")

ax1.legend(loc="lower center")

plt.show()

# %% [markdown]
# # logaritmična skala

# %%
import numpy as np
import matplotlib.pyplot as plt

# Data for plotting
t = np.arange(0.01, 20.0, 0.01)

# Create figure
fig, (ax1, ax2) = plt.subplots(2, 1)

# log y axis
ax1.semilogy(t, np.exp(-t / 5.0))
ax1.set(title='semilogy')
ax1.grid()

# log x axis
ax2.semilogx(t, np.sin(2 * np.pi * t))
ax2.set(title='semilogx')
ax2.grid()

fig.tight_layout()
plt.show()

# %% [markdown]
# ## Gridlines

# %%
subset = data.iloc[:5, 2:14]

fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(subset.iloc[0, :], label="NICOBAR")
ax1.plot(subset.iloc[1, :], label="SOUTH ANDAMAN")
ax1.plot(subset.iloc[2, :], label="N & M ANDAMAN")
ax1.plot(subset.iloc[3, :], label="LOHIT")
ax1.plot(subset.iloc[4, :], label="EAST SIANG")

ax1.legend()

ax1.minorticks_on() # potrebno definirat, da se pokažejo minor gridlines
ax1.grid(True, axis="y", which="both", linestyle="--")

plt.show()

# %% [markdown]
# # Saving plot

# %%
subset = data.iloc[:5, 2:14]

fig = plt.figure(figsize=(12, 7))
ax1 = fig.add_subplot(1, 1, 1)

ax1.plot(subset.iloc[0, :], label="NICOBAR")
ax1.plot(subset.iloc[1, :], label="SOUTH ANDAMAN")
ax1.plot(subset.iloc[2, :], label="N & M ANDAMAN")
ax1.plot(subset.iloc[3, :], label="LOHIT")
ax1.plot(subset.iloc[4, :], label="EAST SIANG")

ax1.legend()

ax1.minorticks_on() # potrebno definirat, da se pokažejo minor gridlines
ax1.grid(True, axis="y", which="both", linestyle="--")

fig.savefig("mojgraf.png", facecolor="gray")
plt.show()

# %%
subset = data.iloc[:5, 2:14]

plt.plot(subset.iloc[0, :], label="NICOBAR")
plt.plot(subset.iloc[1, :], label="SOUTH ANDAMAN")
plt.plot(subset.iloc[2, :], label="N & M ANDAMAN")
plt.plot(subset.iloc[3, :], label="LOHIT")
plt.plot(subset.iloc[4, :], label="EAST SIANG")

plt.legend()

plt.minorticks_on() # potrebno definirat, da se pokažejo minor gridlines
plt.grid(True, axis="y", which="both", linestyle="--")

#plt.show()
plt.savefig("mojgraf.png", facecolor="gray")
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Bar plots

# %%
data.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %% [markdown]
# ### Creating Bars

# %% [markdown]
# <p><img alt="Matplotlib Barplot Positioning" src="images/matplotlib_barplot_positioning.png"></p>

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["ANNUAL"])

plt.show()

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["ANNUAL"], width=0.3)

plt.show()

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["ANNUAL"], 
       width=0.3,
      align="edge")

plt.show()

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["ANNUAL"], 
       width=-0.3,
      align="edge")

plt.show()

# %% [markdown]
# ### Aligning Axis Ticks And Labels

# %% [markdown]
# * [Axes.set_xticks()](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticks.html)
# * [Axes.set_xticklabels()](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.set_xticklabels.html).

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["ANNUAL"])

ax.set_xticks([0,1,2,3,4,5])
ax.set_xticklabels(["a", "b", "c", "d", "e", "f"], rotation=90)

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Horizontal Bar Plot

# %%
subset = data[data["STATE_UT_NAME"] == "ANDAMAN And NICOBAR ISLANDS"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.barh(subset["DISTRICT"], subset["ANNUAL"])

plt.show()

# %% [markdown]
# ---

# %% [markdown]
# # Stacked Bar plot

# %%
data.head()
# Out:
#                  STATE_UT_NAME       DISTRICT    JAN   FEB    MAR    APR  \
# 0  ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3  57.9   65.2  117.0
# 1  ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7  26.0   18.6   90.5
# 2  ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7  15.9    8.6   53.4
# 3            ARUNACHAL PRADESH          LOHIT   42.2  80.8  176.4  358.5
# 4            ARUNACHAL PRADESH     EAST SIANG   33.3  79.5  105.9  216.5
#
#      MAY    JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0  358.5  295.5  285.0  271.9  354.8  326.0  315.2  250.9  2805.2    165.2
# 1  374.4  457.2  421.3  423.1  455.6  301.2  275.8  128.3  3015.7     69.7
# 2  343.6  503.3  465.4  460.9  454.8  276.1  198.6  100.0  2913.3     48.6
# 3  306.4  447.0  660.1  427.8  313.6  167.1   34.1   29.8  3043.8    123.0
# 4  323.0  738.3  990.9  711.2  568.0  206.9   29.5   31.7  4034.7    112.8
#
#    Mar-May  Jun-Sep  Oct-Dec
# 0    540.7   1207.2    892.1
# ...

# %%
#ARUNACHAL PRADESH
subset = data[data["STATE_UT_NAME"] == "ARUNACHAL PRADESH"]

fig = plt.figure(figsize=(15, 10))
ax = fig.add_subplot(1, 1, 1)

ax.bar(subset["DISTRICT"], subset["Jan-Feb"], label="Jan-Feb")
ax.bar(subset["DISTRICT"], subset["Mar-May"], label="Mar-May", bottom=subset["Jan-Feb"])
ax.bar(subset["DISTRICT"], subset["Jun-Sep"], label="Jun-Sep", bottom=subset.loc[:, "Jan-Feb":"Mar-May"].sum(axis=1))
ax.bar(subset["DISTRICT"], subset["Oct-Dec"], label="Oct-Dec", bottom=subset.loc[:, "Jan-Feb":"Jun-Sep"].sum(axis=1))

ax.set_xticks(subset["DISTRICT"])
ax.set_xticklabels(subset["DISTRICT"], rotation=45)

ax.set_xlabel("Okrožja")
ax.set_ylabel("Padavin [mm]")
ax.set_title("Padavine obdobji v okrožjih ARUNCHAL PRADESH")

ax.legend(prop={'size': 20})

plt.show()

# %% [markdown]
# ----

# %% [markdown]
# # Histogram

# %% [markdown]
# [Axes.hist()](https://matplotlib.org/stable/api/_as_gen/matplotlib.axes.Axes.hist.html)

# %%
subset = data[data["STATE_UT_NAME"] == "UTTAR PRADESH"]

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

ax.hist(subset["JAN"])

plt.show()

# %%
data.head(20)
# Out:
#                   STATE_UT_NAME       DISTRICT    JAN    FEB    MAR    APR  \
# 0   ANDAMAN And NICOBAR ISLANDS        NICOBAR  107.3   57.9   65.2  117.0
# 1   ANDAMAN And NICOBAR ISLANDS  SOUTH ANDAMAN   43.7   26.0   18.6   90.5
# 2   ANDAMAN And NICOBAR ISLANDS  N & M ANDAMAN   32.7   15.9    8.6   53.4
# 3             ARUNACHAL PRADESH          LOHIT   42.2   80.8  176.4  358.5
# 4             ARUNACHAL PRADESH     EAST SIANG   33.3   79.5  105.9  216.5
# 5             ARUNACHAL PRADESH  SUBANSIRI F.D   28.0   48.3   85.3  101.5
# 6             ARUNACHAL PRADESH          TIRAP   42.2   72.7  141.0  316.9
# 7             ARUNACHAL PRADESH  ANJAW (LOHIT)   42.2   80.8  176.4  358.5
# 8             ARUNACHAL PRADESH   LOWER DIBANG   83.7  153.9  303.5  383.6
# 9             ARUNACHAL PRADESH      CHANGLANG   70.3  170.9  367.9  554.4
# 10            ARUNACHAL PRADESH     PAPUM PARE   33.5   67.8  106.1  226.9
# ...

# %%
states = data["STATE_UT_NAME"].unique()
fig = plt.figure(figsize=(10, 4*len(states)))

for i, state in enumerate(states):
    ax = fig.add_subplot(len(states), 1, i+1)
    subset = data.loc[data["STATE_UT_NAME"] == state, "Jun-Sep"]
    ax.hist(subset, range=(0, 3000), bins=20)

plt.show()

# %% [markdown]
# # Anotacije

# %%
import matplotlib.pyplot as plt
import math

X = [math.radians(x) for x in range(-180, 180)]
C = [math.cos(i) for i in X]
S = [math.sin(i) for i in X]

plt.plot(X, C, color="blue", linewidth=1.0, linestyle="-", label="cosinus")
plt.plot(X, S, color="red", linewidth=5.0, linestyle="--", label="sinus")

plt.xlim(-3, 5)
plt.ylim(-1, 2)

t = 2*3.14/3
plt.annotate(r"$\sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$", 
             xy=(t, math.sin(t)), 
             fontsize=16,
            arrowprops=dict(arrowstyle="->"),
            xytext=(10, +30),
            textcoords="offset points")

plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # Pandas.plot()

# %%
import pandas as pd
# %matplotlib inline

# %%
df = pd.read_csv("./data/college_majors.csv")
df
# Out:
#      Rank  Major_code                                      Major    Total  \
# 0       1        2419                      PETROLEUM ENGINEERING   2339.0
# 1       2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2       3        2415                  METALLURGICAL ENGINEERING    856.0
# 3       4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4       5        2405                       CHEMICAL ENGINEERING  32260.0
# ..    ...         ...                                        ...      ...
# 168   169        3609                                    ZOOLOGY   8409.0
# 169   170        5201                     EDUCATIONAL PSYCHOLOGY   2854.0
# 170   171        5202                        CLINICAL PSYCHOLOGY   2838.0
# 171   172        5203                      COUNSELING PSYCHOLOGY   4626.0
# 172   173        3501                            LIBRARY SCIENCE   1098.0
#
#          Men    Women            Major_category  ShareWomen  Sample_size  \
# ...

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])
# Out:
# <AxesSubplot:xlabel='Rank'>

# %%
df.plot(x="Rank", y=["P25th", "Median", "P75th"])
plt.show()

# %% [markdown]
# -----

# %%
df["Median"].plot(kind="hist")
plt.show()

# %%
top_5 = df.sort_values(by="Median", ascending=False).head()
top_5
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
top_5.plot(x="Major", y="Median", kind="bar", rot=45, fontsize=7)
plt.show()

# %% [markdown]
# ----

# %%
top_medians = df[df["Median"] > 60000].sort_values("Median")
top_medians.loc[:, ["Rank", "Major", "Median"]]
# Out:
#    Rank                                      Major  Median
# 6     7                          ACTUARIAL SCIENCE   62000
# 7     8                 ASTRONOMY AND ASTROPHYSICS   62000
# 4     5                       CHEMICAL ENGINEERING   65000
# 5     6                        NUCLEAR ENGINEERING   65000
# 3     4  NAVAL ARCHITECTURE AND MARINE ENGINEERING   70000
# 2     3                  METALLURGICAL ENGINEERING   73000
# 1     2             MINING AND MINERAL ENGINEERING   75000
# 0     1                      PETROLEUM ENGINEERING  110000

# %%
top_medians.plot(x="Major", y=["P25th", "Median", "P75th"], kind="bar")
plt.show()

# %% [markdown]
# ---

# %%
df.plot(x="Median", y="Unemployment_rate", kind="scatter")
plt.show()

# %%
cat_totals = df.groupby("Major_category")["Total"].sum().sort_values()
cat_totals
# Out:
# Major_category
# Interdisciplinary                        12296.0
# Agriculture & Natural Resources          75620.0
# Law & Public Policy                     179107.0
# Physical Sciences                       185479.0
# Industrial Arts & Consumer Services     229792.0
# Computers & Mathematics                 299008.0
# Arts                                    357130.0
# Communications & Journalism             392601.0
# Biology & Life Science                  453862.0
# Health                                  463230.0
# Psychology & Social Work                481007.0
# Social Science                          529966.0
# Engineering                             537583.0
# Education                               559129.0
# Humanities & Liberal Arts               713468.0
# Business                               1302376.0
# Name: Total, dtype: float64

# %%
cat_totals.plot(kind="pie", label="")
plt.show()
