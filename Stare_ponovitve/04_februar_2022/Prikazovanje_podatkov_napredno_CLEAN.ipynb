# %% [markdown]
# # Prikazovanje podatkov - napredno

# %% [markdown]
# ## Improving Plot Aesthetics

# %% [markdown]
# ### Introduction To The Data

# %%
import pandas as pd

# %%
women_degrees = pd.read_csv('data/percent-bachelors-degrees-women-usa.csv')
women_degrees.head()
# Out:
#    Year  Agriculture  Architecture  Art and Performance    Biology   Business  \
# 0  1970     4.229798     11.921005                 59.7  29.088363   9.064439
# 1  1971     5.452797     12.003106                 59.9  29.394403   9.503187
# 2  1972     7.420710     13.214594                 60.4  29.810221  10.558962
# 3  1973     9.653602     14.791613                 60.2  31.147915  12.804602
# 4  1974    14.074623     17.444688                 61.9  32.996183  16.204850
#
#    Communications and Journalism  Computer Science  Education  Engineering  \
# 0                           35.3              13.6  74.535328          0.8
# 1                           35.5              13.6  74.149204          1.0
# 2                           36.6              14.9  73.554520          1.2
# 3                           38.4              16.4  73.501814          1.6
# 4                           40.5              18.9  73.336811          2.2
#
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(women_degrees["Year"], women_degrees["Biology"])
plt.show()

# %%
plt.plot(women_degrees["Year"], women_degrees["Biology"], label="Women")
plt.plot(women_degrees["Year"], 100-women_degrees["Biology"], label="Men")
plt.legend()
plt.title("Percentage of Biology Degrees by Gender")

plt.show()

# %% [markdown]
# ### Data-Ink Ratio

# %% [markdown]
# <p>The following is an animated GIF by <a target="_blank" href="https://www.darkhorseanalytics.com/blog/data-looks-better-naked">Darkhorse Analytics</a> that shows a series of tweaks for boosting the data-ink ratio:</p>
# <p><img alt="Darkhorse Analytics GIF" src="images/data-ink.gif"></p>

# %% [markdown]
# ### Hiding Tick Marks

# %%
fig, ax = plt.subplots()

ax.plot(women_degrees["Year"], women_degrees["Biology"], label="Women")
ax.plot(women_degrees["Year"], 100-women_degrees["Biology"], label="Men")
ax.legend()
ax.set_title("Percentage of Biology Degrees by Gender")

ax.tick_params(left=False, bottom=False)

plt.show()

# %%
ax.spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x7fa1539d8ee0>),
#              ('right', <matplotlib.spines.Spine at 0x7fa1539d8fd0>),
#              ('bottom', <matplotlib.spines.Spine at 0x7fa1539d5130>),
#              ('top', <matplotlib.spines.Spine at 0x7fa1539d5250>)])

# %% [markdown]
# ### Hiding Spines

# %%
fig, ax = plt.subplots()

ax.plot(women_degrees["Year"], women_degrees["Biology"], label="Women")
ax.plot(women_degrees["Year"], 100-women_degrees["Biology"], label="Men")
ax.legend()
ax.set_title("Percentage of Biology Degrees by Gender")

ax.tick_params(left=False, bottom=False)

for key, spine in ax.spines.items():
    spine.set_visible(False)

plt.show()

# %% [markdown]
# ### Comparing data with multiple plots

# %% [markdown]
# <p><img alt="Four Major Categories" src="images/four_major_categories_plots.png"></p>

# %%
major_cats = ["Biology", "Computer Science", "Engineering", "Math and Statistics"]
fig = plt.figure(figsize=(12, 12))

for sp in range(0, 4):
    ax = fig.add_subplot(2, 2, sp+1)
    ax.plot(women_degrees["Year"], women_degrees[major_cats[sp]], label="Women")
    ax.plot(women_degrees["Year"], 100-women_degrees[major_cats[sp]], label="Men")
    ax.set_title(major_cats[sp])
    ax.tick_params(left=False, bottom=False)
    ax.set_ylim(0, 100)
    for key, spine in ax.spines.items():
        spine.set_visible(False)

        
ax.legend()
plt.show()

# %% [markdown]
# ## Color, Layout, and Annotations

# %% [markdown]
# ### Color

# %% [markdown]
# [Ishihara test](https://en.wikipedia.org/wiki/Ishihara_test) je najbolj poznan test barvne slepote, kjer mora oseba prepoznati številko zapisano na sliki:
#
# <p><img alt="Ishihara color test plate" src="images/ishihara_test.png"></p>

# %% [markdown]
# ### Setting Line Color Using RGB

# %% [markdown]
# <p><img alt="Tableau RGB values" src="images/tableau_rgb_values.png"></p>

# %%
cb_dark_blue = (200/255, 82/255, 0/255)
cb_orange = (255/255, 188/255, 121/255)

major_cats = ["Biology", "Computer Science", "Engineering", "Math and Statistics"]
fig = plt.figure(figsize=(12, 12))

for sp in range(0, 4):
    ax = fig.add_subplot(2, 2, sp+1)
    ax.plot(women_degrees["Year"], women_degrees[major_cats[sp]], label="Women", c=cb_dark_blue)
    ax.plot(women_degrees["Year"], 100-women_degrees[major_cats[sp]], label="Men", c=cb_orange)
    ax.set_title(major_cats[sp])
    ax.tick_params(left=False, bottom=False)
    ax.set_ylim(0, 100)
    for key, spine in ax.spines.items():
        spine.set_visible(False)

        
ax.legend()
plt.show()

# %% [markdown]
# ### Setting Line Width

# %%
cb_dark_blue = (200/255, 82/255, 0/255)
cb_orange = (255/255, 188/255, 121/255)

major_cats = ["Biology", "Computer Science", "Engineering", "Math and Statistics"]
fig = plt.figure(figsize=(12, 12))

for sp in range(0, 4):
    ax = fig.add_subplot(2, 2, sp+1)
    ax.plot(women_degrees["Year"], women_degrees[major_cats[sp]], label="Women", c=cb_dark_blue, linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[major_cats[sp]], label="Men", c=cb_orange, linewidth=3)
    ax.set_title(major_cats[sp])
    ax.tick_params(left=False, bottom=False)
    ax.set_ylim(0, 100)
    for key, spine in ax.spines.items():
        spine.set_visible(False)

        
ax.legend()
plt.show()

# %% [markdown]
# ### Replacing the Legend With Annotations

# %% [markdown]
# <p><img alt="Annotated Legend" src="images/annotated_legend.png"></p>

# %%
major_cats = ["Engineering", "Computer Science", "Psychology", "Biology", "Physical Sciences", "Math and Statistics"]

fig = plt.figure(figsize=(20, 4))

for sp in range(0, len(major_cats)):
    ax = fig.add_subplot(1, len(major_cats), sp+1)
    ax.plot(women_degrees["Year"], women_degrees[major_cats[sp]], linewidth=3)
    ax.plot(women_degrees["Year"], 100-women_degrees[major_cats[sp]], linewidth=3)
    ax.tick_params(left=False, bottom=False)
    ax.set_ylim(0, 100)
    for key, spine in ax.spines.items():
        spine.set_visible(False)
    ax.set_title(major_cats[sp])
    
    if sp == 0:
        ax.text(2005, 87, "Men")
        ax.text(2005, 8, "Women")
        
    elif sp == len(major_cats)-1:
        ax.text(2005, 62, "Men")
        ax.text(2005, 35, "WOmen")
        
plt.show()

# %% [markdown]
# ## Visualization with pandas

# %% [markdown]
# ### Our data

# %%
cols = ["Major", "Rank", "Median", "P25th", "P75th"]
data = pd.read_csv("data/recent-grads.csv")
data.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  ...  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976  ...
# 1    679.0     77.0    Engineering    0.101852            7       640  ...
# 2    725.0    131.0    Engineering    0.153037            3       648  ...
# 3   1123.0    135.0    Engineering    0.107313           16       758  ...
# 4  21239.0  11021.0    Engineering    0.341631          289     25694  ...
#
#    Part_time  Full_time_year_round  Unemployed  Unemployment_rate  Median  \
# ...

# %%
data.plot(x="Rank", y=["P25th", "Median", "P75th"])
plt.show()

# %%
data["Median"].plot(kind="hist")
plt.show()

# %%
top_5 = data.sort_values(by="Median", ascending=False).head()
top_5.plot(x="Major", y="Median", kind="bar")
plt.show()

# %% [markdown]
# ## Seaborn

# %% [markdown]
# ### Introduction to Seaborn

# %% [markdown]
# <p><img alt="Seaborn Gallery" src="images/seaborn_gallery.png"></p>

# %% [markdown]
# ### Introduction to the Data Set

# %%
titanic = pd.read_csv("data/train.csv")
print(titanic.info())
titanic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
# ...

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
titanic = titanic[cols].dropna()
print(titanic.info())
titanic.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 712 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  712 non-null    int64
#  1   Pclass    712 non-null    int64
#  2   Sex       712 non-null    object
#  3   Age       712 non-null    float64
#  4   SibSp     712 non-null    int64
#  5   Parch     712 non-null    int64
#  6   Fare      712 non-null    float64
#  7   Embarked  712 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 50.1+ KB
# None
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %% [markdown]
# ### Creating Histograms In Seaborn

# %%
import seaborn as sns

# %%
sns.histplot(titanic["Age"], kde=True, stat="density")
plt.show()

# %% [markdown]
# ### Modifying The Appearance Of The Plots

# %% [markdown]
# Celotno barvno shemo grafov lahko spreminjamo preko `sns.set_style`, kjer lahko uporabimo:
# * `darkgrid`: Coordinate grid displayed, dark background color
# * `whitegrid`: Coordinate grid displayed, white background color
# * `dark`: Coordinate grid hidden, dark background color
# * `white`: Coordinate grid hidden, white background color
# * `ticks`: Coordinate grid hidden, white background color, ticks visible
# <p><img alt="Seaborn All Styles" src="images/seaborn_all_styles.png"></p>

# %%
sns.set_style("dark")
sns.histplot(titanic["Age"])
plt.show()

# %% [markdown]
# ### Conditional Plots

# %% [markdown]
# <p><img alt="Simple Conditional KDE Plot" src="images/seaborn_simple_conditional.png"></p>

# %%
g = sns.FacetGrid(titanic, col="Survived", height=5)
g.map(sns.histplot, "Age")
plt.show()

# %%
g = sns.FacetGrid(titanic, col="Pclass", row="Survived", hue="Sex", height=5)
g.map(sns.histplot, "Age")
plt.show()

# %% [markdown]
# ###  Adding A Legend

# %%
g = sns.FacetGrid(titanic, col="Pclass", row="Survived", hue="Sex", height=5)
g.map(sns.histplot, "Age")
g.add_legend()
plt.show()
