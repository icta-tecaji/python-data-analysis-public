# %% [markdown]
# # Pandas

# %% [markdown]
# # Importing pandas

# %% [markdown]
# ```sh
# $ pip install pandas
# ```

# %%
import pandas as pd

# %% [markdown]
# # Basic objects in pandas

# %% [markdown]
# # Series

# %%
import numpy as np

# %%
data = np.array(["a", "b", "c", "d", "e"])
s = pd.Series(data)

print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 0    a
# 1    b
# 2    c
# 3    d
# 4    e
# dtype: object

# %%
# Index lahko explicitno doloičimo
data = np.array(["a", "b", "c", "d", "e"])
s = pd.Series(data, index=[100, 101, 102, 103, 104])
print(s)
# Out:
# 100    a
# 101    b
# 102    c
# 103    d
# 104    e
# dtype: object

# %%
data = np.array(["a", "b", "c", "d", "e"])
s = pd.Series(data, index=[100, 101, 102, 103, 104, 105, 106, 107, 108])
print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 2
#       1 data = np.array(["a", "b", "c", "d", "e"])
# ----> 2 s = pd.Series(data, index=[100, 101, 102, 103, 104, 105, 106, 107, 108])
#       3 print(s)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\series.py:461, in Series.__init__(self, data, index, dtype, name, copy, fastpath)
#     459     index = default_index(len(data))
#     460 elif is_list_like(data):
# --> 461     com.require_length_match(data, index)
#     463 # create/copy the manager
#     464 if isinstance(data, (SingleBlockManager, SingleArrayManager)):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (5) does not match length of index (9)

# %%
# Creating series with dictionary
s = pd.Series({1:"a", 2:"b", 3:"c", 4:"d", 5:"e"})
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 1    a
# 2    b
# 3    c
# 4    d
# 5    e
# dtype: object

# %%
s = pd.Series({1:"a", 2:"b", 3:"c", 4:"d", 5:"e"}, index=[1,3,5,7,9])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# 1      a
# 3      c
# 5      e
# 7    NaN
# 9    NaN
# dtype: object

# %%
# Series of same values
s = pd.Series("a", index=[1,2,3,4,6])
print(s)
print(type(s))
# Out:
# 1    a
# 2    a
# 3    a
# 4    a
# 6    a
# dtype: object
# <class 'pandas.core.series.Series'>

# %% [markdown]
# ---

# %%
s = pd.Series([1,2,3,4,5], index=["a", "b", "c", "d", "e"])
print(type(s))
print(s)
# Out:
# <class 'pandas.core.series.Series'>
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
print(s.index)
print(s.values)
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')
# [1 2 3 4 5]

# %%
print(type(s.values))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ## Dataframe

# %% [markdown]
# ![dataframe](images/df_exploded_resized.svg)

# %%
# Creating a DataFrame from series
data = {
    "one": pd.Series([10, 20, 30]),
    "two": pd.Series([40, 50, 50])
}

df = pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    one  two
# 0   10   40
# 1   20   50
# 2   30   50

# %%
data = {
    "one": pd.Series([10, 20, 30], index=["a", "b", "c"]),
    "two": pd.Series(["x", "y", "z"], index=["a", "b", "d"])
}
df = pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#     one  two
# a  10.0    x
# b  20.0    y
# c  30.0  NaN
# d   NaN    z

# %%
# Defining DataFrame with python list
df = pd.DataFrame([1,2,3,4])
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
# Defining DataFrame with list of lists
data = [["Alex", 10],
       ["Bob", 12],
       ["Claire", 14]]
df = pd.DataFrame(data)
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#         0   1
# 0    Alex  10
# 1     Bob  12
# 2  Claire  14

# %%
# Sapecifying column names
data = [["Alex", 10],
       ["Bob", 12],
       ["Claire", 14]]
df = pd.DataFrame(data, columns=["Name", "Age"])
print(type(df))
print(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
#      Name  Age
# 0    Alex   10
# 1     Bob   12
# 2  Claire   14

# %% [markdown]
# ---

# %% [markdown]
# # Importing real case data

# %% [markdown]
# Stolpce katere bomo uporabljali so:
# * `company` - ime podjetja
# * `rank` - kje na lestvici top 500 se podjetje nahaja
# * `revenues` - koliko prihodka je imelo podjetje, v miljon dolarjih
# * `revenue_change` - kolikšna je bila sprememba dobička med zdajšnjim in prejšnjim letom, izraženo v procentih (%)
# * `profits` - kolikšen je bil profit podjetja, izražen v miljon dolarjih
# * `ceo` - kdo je glavni direktor podjetja
# * `industry` - v kateri industriji podjetje deluje
# * `sector` - v katerem sektorju podjetje deluje
# * `previous_rank` - lanskoletni Global 500 rank podjetja
# * `country` - država v kateri se nahajajo glavne pisarne podjetja

# %%
import pandas as pd

f500 = pd.read_csv("data/f500.csv")
print(type(f500))
print(f500.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (500, 17)

# %% [markdown]
# [DataFrame.head()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.head.html)

# %%
f500.head()
# Out:
#                     company  rank  revenues  revenue_change  profits  assets  \
# 0                   Walmart     1    485873             0.8  13643.0  198825
# 1                State Grid     2    315199            -4.4   9571.3  489838
# 2             Sinopec Group     3    267518            -9.1   1257.9  310726
# 3  China National Petroleum     4    262573           -12.3   1867.5  585619
# 4              Toyota Motor     5    254694             7.7  16899.3  437575
#
#    profit_change                  ceo                  industry  \
# 0           -7.2  C. Douglas McMillon     General Merchandisers
# 1           -6.2              Kou Wei                 Utilities
# 2          -65.0            Wang Yupu        Petroleum Refining
# 3          -73.7        Zhang Jianhua        Petroleum Refining
# 4          -12.3          Akio Toyoda  Motor Vehicles and Parts
#
#                    sector  previous_rank country      hq_location  \
# 0               Retailing              1     USA  Bentonville, AR
# 1                  Energy              2   China   Beijing, China
# 2                  Energy              4   China   Beijing, China
# 3                  Energy              3   China   Beijing, China
# 4  Motor Vehicles & Parts              8   Japan    Toyota, Japan
#
#                         website  years_on_global_500_list  employees  \
# 0        http://www.walmart.com                        23    2300000
# 1        http://www.sgcc.com.cn                        17     926067
# 2        http://www.sinopec.com                        19     713288
# 3        http://www.cnpc.com.cn                        17    1512048
# 4  http://www.toyota-global.com                        23     364445
#
#    total_stockholder_equity
# 0                     77798
# 1                    209456
# 2                    106523
# 3                    301893
# 4                    157210

# %%
f500.tail(10)
# Out:
#                                    company  rank  revenues  revenue_change  \
# 490                          National Grid   491     22036            -3.2
# 491                         Dollar General   492     21987             7.9
# 492                         Telecom Italia   493     21941           -17.4
# 493               Xiamen ITG Holding Group   494     21930            34.3
# 494  Xinjiang Guanghui Industry Investment   495     21919            31.1
# 495         Teva Pharmaceutical Industries   496     21903            11.5
# 496               New China Life Insurance   497     21796           -13.3
# 497              Wm. Morrison Supermarkets   498     21741           -11.3
# 498                                    TUI   499     21655            -5.5
# 499                             AutoNation   500     21609             3.6
#
#      profits  assets  profit_change                 ceo  \
# 490  10150.6   82310          160.2      John Pettigrew
# 491   1251.1   11672            7.4       Todd J. Vasos
# 492   1999.4   74295            NaN     Flavio Cattaneo
# 493     35.6   12161          -25.1           Xu Xiaoxi
# 494    251.8   31957           49.9       Shang Jiqiang
# 495    329.0   92890          -79.3   Yitzhak Peterburg
# 496    743.9  100609          -45.6            Wan Feng
# 497    406.4   11630           20.4      David T. Potts
# 498   1151.7   16247          195.5   Friedrich Joussen
# 499    430.5   10060           -2.7  Michael J. Jackson
#
#                             industry              sector  previous_rank  \
# 490                        Utilities              Energy            471
# 491              Specialty Retailers           Retailing              0
# 492               Telecommunications  Telecommunications            404
# 493                          Trading         Wholesalers              0
# 494                          Trading         Wholesalers              0
# 495                  Pharmaceuticals         Health Care              0
# 496  Insurance: Life, Health (stock)          Financials            427
# 497             Food and Drug Stores  Food & Drug Stores            437
# 498                  Travel Services   Business Services            467
# 499              Specialty Retailers           Retailing              0
#
#      country           hq_location                       website  \
# 490  Britain       London, Britain   http://www.nationalgrid.com
# 491      USA    Goodlettsville, TN  http://www.dollargeneral.com
# 492    Italy          Milan, Italy  http://www.telecomitalia.com
# 493    China         Xiamen, China  http://www.itgholding.com.cn
# 494    China         Urumqi, China       http://www.guanghui.com
# 495   Israel  Petach Tikva, Israel      http://www.tevapharm.com
# 496    China        Beijing, China   http://www.newchinalife.com
# 497  Britain     Bradford, Britain      http://www.morrisons.com
# 498  Germany      Hanover, Germany       http://www.tuigroup.com
# 499      USA   Fort Lauderdale, FL     http://www.autonation.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 490                        12      22132                     25463
# 491                         1     121000                      5406
# 492                        18      61227                     22366
# 493                         1      18454                      1066
# 494                         1      65616                      4563
# 495                         1      56960                     33337
# 496                         2      54378                      8507
# 497                        13      77210                      5111
# 498                        23      66779                      3006
# 499                        12      26000                      2310

# %%
f500
# Out:
#                             company  rank  revenues  revenue_change  profits  \
# 0                           Walmart     1    485873             0.8  13643.0
# 1                        State Grid     2    315199            -4.4   9571.3
# 2                     Sinopec Group     3    267518            -9.1   1257.9
# 3          China National Petroleum     4    262573           -12.3   1867.5
# 4                      Toyota Motor     5    254694             7.7  16899.3
# ..                              ...   ...       ...             ...      ...
# 495  Teva Pharmaceutical Industries   496     21903            11.5    329.0
# 496        New China Life Insurance   497     21796           -13.3    743.9
# 497       Wm. Morrison Supermarkets   498     21741           -11.3    406.4
# 498                             TUI   499     21655            -5.5   1151.7
# 499                      AutoNation   500     21609             3.6    430.5
#
#      assets  profit_change                  ceo  \
# 0    198825           -7.2  C. Douglas McMillon
# 1    489838           -6.2              Kou Wei
# 2    310726          -65.0            Wang Yupu
# 3    585619          -73.7        Zhang Jianhua
# 4    437575          -12.3          Akio Toyoda
# ..      ...            ...                  ...
# 495   92890          -79.3    Yitzhak Peterburg
# 496  100609          -45.6             Wan Feng
# 497   11630           20.4       David T. Potts
# 498   16247          195.5    Friedrich Joussen
# 499   10060           -2.7   Michael J. Jackson
#
#                             industry                  sector  previous_rank  \
# 0              General Merchandisers               Retailing              1
# 1                          Utilities                  Energy              2
# 2                 Petroleum Refining                  Energy              4
# 3                 Petroleum Refining                  Energy              3
# 4           Motor Vehicles and Parts  Motor Vehicles & Parts              8
# ..                               ...                     ...            ...
# 495                  Pharmaceuticals             Health Care              0
# 496  Insurance: Life, Health (stock)              Financials            427
# 497             Food and Drug Stores      Food & Drug Stores            437
# 498                  Travel Services       Business Services            467
# 499              Specialty Retailers               Retailing              0
#
#      country           hq_location                       website  \
# 0        USA       Bentonville, AR        http://www.walmart.com
# 1      China        Beijing, China        http://www.sgcc.com.cn
# 2      China        Beijing, China        http://www.sinopec.com
# 3      China        Beijing, China        http://www.cnpc.com.cn
# 4      Japan         Toyota, Japan  http://www.toyota-global.com
# ..       ...                   ...                           ...
# 495   Israel  Petach Tikva, Israel      http://www.tevapharm.com
# 496    China        Beijing, China   http://www.newchinalife.com
# 497  Britain     Bradford, Britain      http://www.morrisons.com
# 498  Germany      Hanover, Germany       http://www.tuigroup.com
# 499      USA   Fort Lauderdale, FL     http://www.autonation.com
#
#      years_on_global_500_list  employees  total_stockholder_equity
# 0                          23    2300000                     77798
# 1                          17     926067                    209456
# 2                          19     713288                    106523
# 3                          17    1512048                    301893
# 4                          23     364445                    157210
# ..                        ...        ...                       ...
# 495                         1      56960                     33337
# 496                         2      54378                      8507
# 497                        13      77210                      5111
# 498                        23      66779                      3006
# 499                        12      26000                      2310
#
# [500 rows x 17 columns]

# %%
f500.columns
# Out:
# Index(['company', 'rank', 'revenues', 'revenue_change', 'profits', 'assets',
#        'profit_change', 'ceo', 'industry', 'sector', 'previous_rank',
#        'country', 'hq_location', 'website', 'years_on_global_500_list',
#        'employees', 'total_stockholder_equity'],
#       dtype='object')

# %%
f500.index
# Out:
# RangeIndex(start=0, stop=500, step=1)

# %%
import pandas as pd
f500 = pd.read_csv("data/f500.csv", index_col = "company")
print(type(f500))
print(f500.shape)
print(f500.index)
f500.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (500, 16)
# Index(['Walmart', 'State Grid', 'Sinopec Group', 'China National Petroleum',
#        'Toyota Motor', 'Volkswagen', 'Royal Dutch Shell', 'Berkshire Hathaway',
#        'Apple', 'Exxon Mobil',
#        ...
#        'National Grid', 'Dollar General', 'Telecom Italia',
#        'Xiamen ITG Holding Group', 'Xinjiang Guanghui Industry Investment',
#        'Teva Pharmaceutical Industries', 'New China Life Insurance',
#        'Wm. Morrison Supermarkets', 'TUI', 'AutoNation'],
#       dtype='object', name='company', length=500)
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %% [markdown]
# ---

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int64
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             500 non-null    int64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
#  13  years_on_global_500_list  500 non-null    int64
#  14  employees                 500 non-null    int64
#  15  total_stockholder_equity  500 non-null    int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 66.4+ KB

# %%
import pandas as pd
import numpy as np
f500 = pd.read_csv("data/f500.csv", index_col="company", dtype={"rank": np.int16})
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int16
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             500 non-null    int64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
#  13  years_on_global_500_list  500 non-null    int64
#  14  employees                 500 non-null    int64
#  15  total_stockholder_equity  500 non-null    int64
# dtypes: float64(3), int16(1), int64(6), object(6)
# memory usage: 63.5+ KB

# %% [markdown]
# ## Categorical Data

# %%
s = pd.Series(["sl", "hr", "at", "sl", "de"], dtype="category")
s
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: category
# Categories (4, object): ['at', 'de', 'hr', 'sl']

# %%
s = pd.Series(["sl", "hr", "at", "sl", "de"])
print(s)

s = s.astype("category")
s
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: object
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: category
# Categories (4, object): ['at', 'de', 'hr', 'sl']

# %%
s = pd.Series(
    pd.Categorical(["sl", "hr", "at", "sl", "de"], categories=["sl", "hr", "at", "de"])
)
s
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: category
# Categories (4, object): ['sl', 'hr', 'at', 'de']

# %% [markdown]
# ---

# %%
s1 = pd.Series(["sl", "hr", "at", "sl", "de"]*10_000, dtype="object")
print(s1)
s1.memory_usage()
# Out:
# 0        sl
# 1        hr
# 2        at
# 3        sl
# 4        de
#          ..
# 49995    sl
# 49996    hr
# 49997    at
# 49998    sl
# 49999    de
# Length: 50000, dtype: object
# 400128

# %%
s2 = pd.Series(["sl", "hr", "at", "sl", "de"]*10_000, dtype="category")
print(s2)
s2.memory_usage()
# Out:
# 0        sl
# 1        hr
# 2        at
# 3        sl
# 4        de
#          ..
# 49995    sl
# 49996    hr
# 49997    at
# 49998    sl
# 49999    de
# Length: 50000, dtype: category
# Categories (4, object): ['at', 'de', 'hr', 'sl']
# 50332

# %%
s.cat.categories
# Out:
# Index(['sl', 'hr', 'at', 'de'], dtype='object')

# %%
s.cat.codes
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    3
# dtype: int8

# %%
df = pd.DataFrame({"A": ["sl", "hr", "at", "sl", "de"], "B": ["sl", "hr", "at", "sl", "pl"]}, dtype="category")
print(df["A"])
print(df["B"])
df
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# Name: A, dtype: category
# Categories (4, object): ['at', 'de', 'hr', 'sl']
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    pl
# Name: B, dtype: category
# Categories (4, object): ['at', 'hr', 'pl', 'sl']
#     A   B
# 0  sl  sl
# 1  hr  hr
# 2  at  at
# 3  sl  sl
# 4  de  pl

# %%
df = pd.DataFrame({"A": ["sl", "hr", "at", "sl", "de"], "B": ["sl", "hr", "at", "sl", "pl"]})
cat_type = pd.CategoricalDtype(categories=["sl", "at", "hr", "de", "pl"])
df_cat = df.astype(cat_type)

print(df_cat["A"])
print(df_cat["B"])
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# Name: A, dtype: category
# Categories (5, object): ['sl', 'at', 'hr', 'de', 'pl']
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    pl
# Name: B, dtype: category
# Categories (5, object): ['sl', 'at', 'hr', 'de', 'pl']

# %% [markdown]
# ----

# %%
print(s)
s.cat.categories
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: category
# Categories (4, object): ['sl', 'hr', 'at', 'de']
# Index(['sl', 'hr', 'at', 'de'], dtype='object')

# %%
s.cat.rename_categories({"sl": "slovenija", "hr":"hrvaška", "at":"avstrija", "de":"nemčija"})
# Out:
# 0    slovenija
# 1      hrvaška
# 2     avstrija
# 3    slovenija
# 4      nemčija
# dtype: category
# Categories (4, object): ['slovenija', 'hrvaška', 'avstrija', 'nemčija']

# %%
s.cat.rename_categories(["slovenija", "hrvaška", "avstrija", "nemčija"])
# Out:
# 0    slovenija
# 1      hrvaška
# 2     avstrija
# 3    slovenija
# 4      nemčija
# dtype: category
# Categories (4, object): ['slovenija', 'hrvaška', 'avstrija', 'nemčija']

# %%
s.cat.add_categories(["pl"])
# Out:
# 0    sl
# 1    hr
# 2    at
# 3    sl
# 4    de
# dtype: category
# Categories (5, object): ['sl', 'hr', 'at', 'de', 'pl']

# %%
s2 = s.cat.remove_categories(["de"])
print(s2)
print(s2.cat.categories)
print(s2.cat.codes)
# Out:
# 0     sl
# 1     hr
# 2     at
# 3     sl
# 4    NaN
# dtype: category
# Categories (3, object): ['sl', 'hr', 'at']
# Index(['sl', 'hr', 'at'], dtype='object')
# 0    0
# 1    1
# 2    2
# 3    0
# 4   -1
# dtype: int8

# %%
# določimo vrstni red med kategorijam
s = pd.Series(pd.Categorical(["low", "med", "high", "low"]*3, ordered=False))
s.sort_values()
# Out:
# 2     high
# 6     high
# 10    high
# 0      low
# 3      low
# 4      low
# 7      low
# 8      low
# 11     low
# 1      med
# 5      med
# 9      med
# dtype: category
# Categories (3, object): ['high', 'low', 'med']

# %%
s = pd.Series(pd.Categorical(["low", "med", "high", "low"]*3, categories=["low", "med", "high"], ordered=True))
s.sort_values()
# Out:
# 0      low
# 3      low
# 4      low
# 7      low
# 8      low
# 11     low
# 1      med
# 5      med
# 9      med
# 2     high
# 6     high
# 10    high
# dtype: category
# Categories (3, object): ['low' < 'med' < 'high']

# %%
s
# Out:
# 0      low
# 1      med
# 2     high
# 3      low
# 4      low
# 5      med
# 6     high
# 7      low
# 8      low
# 9      med
# 10    high
# 11     low
# dtype: category
# Categories (3, object): ['low' < 'med' < 'high']

# %%
pd.get_dummies(s)
# Out:
#     low  med  high
# 0     1    0     0
# 1     0    1     0
# 2     0    0     1
# 3     1    0     0
# 4     1    0     0
# 5     0    1     0
# 6     0    0     1
# 7     1    0     0
# 8     1    0     0
# 9     0    1     0
# 10    0    0     1
# 11    1    0     0

# %% [markdown]
# # Data Selection / Data Indexing

# %% [markdown]
# ## Selecting Columns by Label - .loc

# %% [markdown]
# `DataFrame.loc[ row_label , column_label ]`.
#
# [DataFrame.loc[  ]](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %%
rank_col = f500.loc[:, "rank"]
print(type(rank_col))
rank_col
# Out:
# <class 'pandas.core.series.Series'>
# company
# Walmart                             1
# State Grid                          2
# Sinopec Group                       3
# China National Petroleum            4
# Toyota Motor                        5
#                                  ...
# Teva Pharmaceutical Industries    496
# New China Life Insurance          497
# Wm. Morrison Supermarkets         498
# TUI                               499
# AutoNation                        500
# Name: rank, Length: 500, dtype: int16

# %%
rank_col = f500["rank"]
print(type(rank_col))
rank_col
# Out:
# <class 'pandas.core.series.Series'>
# company
# Walmart                             1
# State Grid                          2
# Sinopec Group                       3
# China National Petroleum            4
# Toyota Motor                        5
#                                  ...
# Teva Pharmaceutical Industries    496
# New China Life Insurance          497
# Wm. Morrison Supermarkets         498
# TUI                               499
# AutoNation                        500
# Name: rank, Length: 500, dtype: int16

# %%
slice_ = f500.loc[:, ["country", "rank"]]
print(type(slice_))
slice_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                 country  rank
# company
# Walmart                             USA     1
# State Grid                        China     2
# Sinopec Group                     China     3
# China National Petroleum          China     4
# Toyota Motor                      Japan     5
# ...                                 ...   ...
# Teva Pharmaceutical Industries   Israel   496
# New China Life Insurance          China   497
# Wm. Morrison Supermarkets       Britain   498
# TUI                             Germany   499
# AutoNation                          USA   500
#
# [500 rows x 2 columns]

# %%
slice_ = f500[["country", "rank"]]
print(type(slice_))
slice_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                 country  rank
# company
# Walmart                             USA     1
# State Grid                        China     2
# Sinopec Group                     China     3
# China National Petroleum          China     4
# Toyota Motor                      Japan     5
# ...                                 ...   ...
# Teva Pharmaceutical Industries   Israel   496
# New China Life Insurance          China   497
# Wm. Morrison Supermarkets       Britain   498
# TUI                             Germany   499
# AutoNation                          USA   500
#
# [500 rows x 2 columns]

# %%
slice_ = f500.loc[:, "rank":"profits"]
print(type(slice_))
slice_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                                 rank  revenues  revenue_change  profits
# company
# Walmart                            1    485873             0.8  13643.0
# State Grid                         2    315199            -4.4   9571.3
# Sinopec Group                      3    267518            -9.1   1257.9
# China National Petroleum           4    262573           -12.3   1867.5
# Toyota Motor                       5    254694             7.7  16899.3
# ...                              ...       ...             ...      ...
# Teva Pharmaceutical Industries   496     21903            11.5    329.0
# New China Life Insurance         497     21796           -13.3    743.9
# Wm. Morrison Supermarkets        498     21741           -11.3    406.4
# TUI                              499     21655            -5.5   1151.7
# AutoNation                       500     21609             3.6    430.5
#
# [500 rows x 4 columns]

# %%
profits_col = f500.profits
print(type(profits_col))
profits_col
# Out:
# <class 'pandas.core.series.Series'>
# company
# Walmart                           13643.0
# State Grid                         9571.3
# Sinopec Group                      1257.9
# China National Petroleum           1867.5
# Toyota Motor                      16899.3
#                                    ...
# Teva Pharmaceutical Industries      329.0
# New China Life Insurance            743.9
# Wm. Morrison Supermarkets           406.4
# TUI                                1151.7
# AutoNation                          430.5
# Name: profits, Length: 500, dtype: float64

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Select by Label</th>
# <th>Explicit Syntax</th>
# <th>Common Shorthand</th>
# <th>Other Shorthand</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Single column</td>
# <td><code>df.loc[:,"col1"]</code></td>
# <td bgcolor="#00FF00"><code>df["col1"]</code></td>
# <td><code>df.col1</code></td>
# </tr>
# <tr>
# <td>List of columns</td>
# <td><code>df.loc[:,["col1", "col7"]]</code></td>
# <td bgcolor="#00FF00"><code>df[["col1", "col7"]]</code></td>
# <td></td>
# </tr>
# <tr>
# <td>Slice of columns</td>
# <td bgcolor="#00FF00"><code>df.loc[:,"col1":"col4"]</code></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## Select Rows by Label - .loc

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %%
single_row = f500.loc["Sinopec Group", :]
print(type(single_row))
single_row
# Out:
# <class 'pandas.core.series.Series'>
# rank                                             3
# revenues                                    267518
# revenue_change                                -9.1
# profits                                     1257.9
# assets                                      310726
# profit_change                                -65.0
# ceo                                      Wang Yupu
# industry                        Petroleum Refining
# sector                                      Energy
# previous_rank                                    4
# country                                      China
# hq_location                         Beijing, China
# website                     http://www.sinopec.com
# years_on_global_500_list                        19
# employees                                   713288
# total_stockholder_equity                    106523
# Name: Sinopec Group, dtype: object

# %%
single_row = f500.loc["Sinopec Group"]
print(type(single_row))
single_row
# Out:
# <class 'pandas.core.series.Series'>
# rank                                             3
# revenues                                    267518
# revenue_change                                -9.1
# profits                                     1257.9
# assets                                      310726
# profit_change                                -65.0
# ceo                                      Wang Yupu
# industry                        Petroleum Refining
# sector                                      Energy
# previous_rank                                    4
# country                                      China
# hq_location                         Beijing, China
# website                     http://www.sinopec.com
# years_on_global_500_list                        19
# employees                                   713288
# total_stockholder_equity                    106523
# Name: Sinopec Group, dtype: object

# %%
slice_ = f500.loc[["Toyota Motor", "Walmart"], :]
print(type(slice_))
slice_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#               rank  revenues  revenue_change  profits  assets  profit_change  \
# company
# Toyota Motor     5    254694             7.7  16899.3  437575          -12.3
# Walmart          1    485873             0.8  13643.0  198825           -7.2
#
#                               ceo                  industry  \
# company
# Toyota Motor          Akio Toyoda  Motor Vehicles and Parts
# Walmart       C. Douglas McMillon     General Merchandisers
#
#                               sector  previous_rank country      hq_location  \
# company
# Toyota Motor  Motor Vehicles & Parts              8   Japan    Toyota, Japan
# Walmart                    Retailing              1     USA  Bentonville, AR
#
#                                    website  years_on_global_500_list  \
# company
# Toyota Motor  http://www.toyota-global.com                        23
# Walmart             http://www.walmart.com                        23
#
#               employees  total_stockholder_equity
# company
# Toyota Motor     364445                    157210
# Walmart         2300000                     77798

# %%
slice_ = f500.loc["State Grid":"Toyota Motor"]
print(type(slice_))
slice_
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                           rank  revenues  revenue_change  profits  assets  \
# company
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change            ceo  \
# company
# State Grid                         -6.2        Kou Wei
# Sinopec Group                     -65.0      Wang Yupu
# China National Petroleum          -73.7  Zhang Jianhua
# Toyota Motor                      -12.3    Akio Toyoda
#
#                                           industry                  sector  \
# company
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country     hq_location  \
# company
# State Grid                            2   China  Beijing, China
# Sinopec Group                         4   China  Beijing, China
# China National Petroleum              3   China  Beijing, China
# Toyota Motor                          8   Japan   Toyota, Japan
#
#                                                website  \
# company
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %% [markdown]
# ![image](images/df_series_s_updated.svg)

# %% [markdown]
# ![image](images/df_series_df_updated.svg)

# %% [markdown]
# ## Selecting Items - .loc

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %%
walmart_profits = f500.loc["Walmart", "profits"]
print(type(walmart_profits))
walmart_profits
# Out:
# <class 'numpy.float64'>
# 13643.0

# %%
walmart_row = f500.loc["Walmart", :]
print(walmart_row)

print()

walmart_profits = walmart_row.loc["profits"]
print(walmart_profits)
# Out:
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: Walmart, dtype: object
#
# 13643.0

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>Select by Label</th>
# <th>Explicit Syntax</th>
# <th>Shorthand Convention</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>Single column from dataframe</td>
# <td><code>df.loc[:,"col1"]</code></td>
# <td bgcolor="#00FF00"><code>df["col1"]</code></td>
# </tr>
# <tr>
# <td>List of columns from dataframe</td>
# <td><code>df.loc[:,["col1","col7"]]</code></td>
# <td bgcolor="#00FF00"><code>df[["col1","col7"]]</code></td>
# </tr>
# <tr>
# <td>Slice of columns from dataframe</td>
# <td bgcolor="#00FF00"><code>df.loc[:,"col1":"col4"]</code></td>
# <td></td>
# </tr>
# <tr>
# <td>Single row from dataframe</td>
# <td bgcolor="#00FF00"><code>df.loc["row4"]</code></td>
# <td></td>
# </tr>
# <tr>
# <td>List of rows from dataframe</td>
# <td bgcolor="#00FF00"><code>df.loc[["row1", "row8"]]</code></td>
# <td></td>
# </tr>
# <tr>
# <td>Slice of rows from dataframe</td>
# <td bgcolor="#00FF00"><code>df.loc["row3":"row5"]</code></td>
# <td><code>df["row3":"row5"]</code></td>
# </tr>
# <tr>
# <td>Single item from series</td>
# <td><code>s.loc["item8"]</code></td>
# <td bgcolor="#00FF00"><code>s["item8"]</code></td>
# </tr>
# <tr>
# <td>List of items from series</td>
# <td><code>s.loc[["item1","item7"]]</code></td>
# <td bgcolor="#00FF00"><code>s[["item1","item7"]]</code></td>
# </tr>
# <tr>
# <td>Slice of items from series</td>
# <td><code>s.loc["item2":"item4"]</code></td>
# <td bgcolor="#00FF00"><code>s["item2":"item4"]</code></td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ---

# %%
data = f500.loc[["Aviva", "HP", "JD.com", "BHP Billiton"], ["rank", "previous_rank", "profits"]]
data
# Out:
#               rank  previous_rank  profits
# company
# Aviva           90            279    948.8
# HP             194             48   2496.0
# JD.com         261            366   -573.0
# BHP Billiton   350            168  -6385.0

# %% [markdown]
# ## Selecting using .iloc

# %%
f500.loc["Walmart", "sector"]
# Out:
# 'Retailing'

# %%
f500.iloc[0, 8]
# Out:
# 'Retailing'

# %% [markdown]
# ![image](images/selection_iloc.svg)

# %%
f500.iloc[0]
# Out:
# rank                                             1
# revenues                                    485873
# revenue_change                                 0.8
# profits                                    13643.0
# assets                                      198825
# profit_change                                 -7.2
# ceo                            C. Douglas McMillon
# industry                     General Merchandisers
# sector                                   Retailing
# previous_rank                                    1
# country                                        USA
# hq_location                        Bentonville, AR
# website                     http://www.walmart.com
# years_on_global_500_list                        23
# employees                                  2300000
# total_stockholder_equity                     77798
# Name: Walmart, dtype: object

# %%
f500.iloc[:, 6]
# Out:
# company
# Walmart                           C. Douglas McMillon
# State Grid                                    Kou Wei
# Sinopec Group                               Wang Yupu
# China National Petroleum                Zhang Jianhua
# Toyota Motor                              Akio Toyoda
#                                          ...
# Teva Pharmaceutical Industries      Yitzhak Peterburg
# New China Life Insurance                     Wan Feng
# Wm. Morrison Supermarkets              David T. Potts
# TUI                                 Friedrich Joussen
# AutoNation                         Michael J. Jackson
# Name: ceo, Length: 500, dtype: object

# %%
f500.iloc[5:12]
# Out:
#                     rank  revenues  revenue_change  profits  assets  \
# company
# Volkswagen             6    240264             1.5   5937.3  432116
# Royal Dutch Shell      7    240033           -11.8   4575.0  411275
# Berkshire Hathaway     8    223604             6.1  24074.0  620854
# Apple                  9    215639            -7.7  45687.0  321686
# Exxon Mobil           10    205004           -16.7   7840.0  330314
# McKesson              11    198533             3.1   5070.0   60969
# BP                    12    186606           -17.4    115.0  263316
#
#                     profit_change                 ceo  \
# company
# Volkswagen                    NaN     Matthias Muller
# Royal Dutch Shell           135.9     Ben van Beurden
# Berkshire Hathaway            NaN   Warren E. Buffett
# Apple                       -14.4     Timothy D. Cook
# Exxon Mobil                 -51.5     Darren W. Woods
# McKesson                    124.5  John H. Hammergren
# BP                            NaN    Robert W. Dudley
#
#                                                     industry  \
# company
# Volkswagen                          Motor Vehicles and Parts
# Royal Dutch Shell                         Petroleum Refining
# Berkshire Hathaway  Insurance: Property and Casualty (Stock)
# Apple                            Computers, Office Equipment
# Exxon Mobil                               Petroleum Refining
# McKesson                            Wholesalers: Health Care
# BP                                        Petroleum Refining
#
#                                     sector  previous_rank      country  \
# company
# Volkswagen          Motor Vehicles & Parts              7      Germany
# Royal Dutch Shell                   Energy              5  Netherlands
# Berkshire Hathaway              Financials             11          USA
# Apple                           Technology              9          USA
# Exxon Mobil                         Energy              6          USA
# McKesson                       Wholesalers             12          USA
# BP                                  Energy             10      Britain
#
#                                hq_location                           website  \
# company
# Volkswagen              Wolfsburg, Germany         http://www.volkswagen.com
# Royal Dutch Shell   The Hague, Netherlands              http://www.shell.com
# Berkshire Hathaway               Omaha, NE  http://www.berkshirehathaway.com
# Apple                        Cupertino, CA              http://www.apple.com
# Exxon Mobil                     Irving, TX         http://www.exxonmobil.com
# McKesson                 San Francisco, CA           http://www.mckesson.com
# BP                         London, Britain                 http://www.bp.com
#
#                     years_on_global_500_list  employees  \
# company
# Volkswagen                                23     626715
# Royal Dutch Shell                         23      89000
# Berkshire Hathaway                        21     367700
# Apple                                     15     116000
# Exxon Mobil                               23      72700
# McKesson                                  23      64500
# BP                                        23      74500
#
#                     total_stockholder_equity
# company
# Volkswagen                             97753
# Royal Dutch Shell                     186646
# Berkshire Hathaway                    283001
# Apple                                 128249
# Exxon Mobil                           167325
# McKesson                               11095
# BP                                     95286

# %%
f500.iloc[:5, 5:10]
# Out:
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank
# company
# Walmart                               1
# State Grid                            2
# Sinopec Group                         4
# China National Petroleum              3
# Toyota Motor                          8

# %%
f500.iloc[0, "sector"]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:873, in _LocationIndexer._validate_tuple_indexer(self, key)
#     872 try:
# --> 873     self._validate_key(k, i)
#     874 except ValueError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1483, in _iLocIndexer._validate_key(self, key, axis)
#    1482 else:
# -> 1483     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In [244], line 1
# ----> 1 f500.iloc[0, "sector"]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1563, in _iLocIndexer._getitem_tuple(self, tup)
#    1561 def _getitem_tuple(self, tup: tuple):
# -> 1563     tup = self._validate_tuple_indexer(tup)
#    1564     with suppress(IndexingError):
#    1565         return self._getitem_lowerdim(tup)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:875, in _LocationIndexer._validate_tuple_indexer(self, key)
#     873         self._validate_key(k, i)
#     874     except ValueError as err:
# --> 875         raise ValueError(
#     876             "Location based indexing can only have "
#     877             f"[{self._valid_types}] types"
#     878         ) from err
#     879 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %% [markdown]
# ---

# %% [markdown]
# # Vectorized Operations

# %% [markdown]
# ![vectorized](images/vectorized.gif)

# %%
my_series = pd.Series([1,2,3,4,5])
my_series
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
my_series + 10
# Out:
# 0    11
# 1    12
# 2    13
# 3    14
# 4    15
# dtype: int64

# %%
my_series - 10
# Out:
# 0   -9
# 1   -8
# 2   -7
# 3   -6
# 4   -5
# dtype: int64

# %%
my_series * 10
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
my_series / 10
# Out:
# 0    0.1
# 1    0.2
# 2    0.3
# 3    0.4
# 4    0.5
# dtype: float64

# %%
rank_change = f500["previous_rank"] - f500["rank"]
print(type(rank_change))
rank_change
# Out:
# <class 'pandas.core.series.Series'>
# company
# Walmart                             0
# State Grid                          0
# Sinopec Group                       1
# China National Petroleum           -1
# Toyota Motor                        3
#                                  ...
# Teva Pharmaceutical Industries   -496
# New China Life Insurance          -70
# Wm. Morrison Supermarkets         -61
# TUI                               -32
# AutoNation                       -500
# Length: 500, dtype: int64

# %% [markdown]
# # Series Data Exploration Methods

# %%
rank_change.head()
# Out:
# company
# Walmart                     0
# State Grid                  0
# Sinopec Group               1
# China National Petroleum   -1
# Toyota Motor                3
# dtype: int64

# %%
my_series = pd.Series([0,1,2,3,4,5])
my_series.max()
# Out:
# 5

# %%
rank_change_max = rank_change.max()
print(rank_change_max)
# Out:
# 226

# %%
rank_change_min = rank_change.min()
rank_change_min
# Out:
# -500

# %% [markdown]
# ---

# %% [markdown]
# ## Series Describe

# %%
rank_change.describe()
# Out:
# count    500.000000
# mean     -28.366000
# std      108.602823
# min     -500.000000
# 25%      -28.250000
# 50%       -4.000000
# 75%        8.250000
# max      226.000000
# dtype: float64

# %%
country = f500["country"]
country.describe()
# Out:
# count     500
# unique     34
# top       USA
# freq      132
# Name: country, dtype: object

# %%
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %%
f500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int16
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             500 non-null    int64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
#  13  years_on_global_500_list  500 non-null    int64
#  14  employees                 500 non-null    int64
#  15  total_stockholder_equity  500 non-null    int64
# dtypes: float64(3), int16(1), int64(6), object(6)
# memory usage: 79.6+ KB

# %% [markdown]
# ---

# %%
rank_change.value_counts()
# Out:
# -1      14
# -4      13
#  8      12
# -2      12
# -6      11
#         ..
#  85      1
#  105     1
# -30      1
#  144     1
# -500     1
# Length: 185, dtype: int64

# %%
country.value_counts()
# Out:
# USA             132
# China           109
# Japan            51
# Germany          29
# France           29
# Britain          24
# South Korea      15
# Netherlands      14
# Switzerland      14
# Canada           11
# Spain             9
# Australia         7
# Brazil            7
# India             7
# Italy             7
# Taiwan            6
# Russia            4
# Ireland           4
# Singapore         3
# Sweden            3
# Mexico            2
# Malaysia          1
# Thailand          1
# Belgium           1
# Norway            1
# Luxembourg        1
# Indonesia         1
# Denmark           1
# Saudi Arabia      1
# Finland           1
# Venezuela         1
# Turkey            1
# U.A.E             1
# Israel            1
# Name: country, dtype: int64

# %%
import numpy as np


1 + np.nan
# Out:
# nan

# %%
f500["industry"].value_counts()
# Out:
# Banks: Commercial and Savings                     51
# Motor Vehicles and Parts                          34
# Petroleum Refining                                28
# Insurance: Life, Health (stock)                   24
# Food and Drug Stores                              20
# Mining, Crude-Oil Production                      18
# Telecommunications                                18
# Utilities                                         18
# Insurance: Property and Casualty (Stock)          18
# Trading                                           15
# Pharmaceuticals                                   15
# Aerospace and Defense                             14
# Electronics, Electrical Equip.                    13
# Engineering, Construction                         13
# Energy                                            12
# Metals                                            12
# Industrial Machinery                              10
# Specialty Retailers                               10
# Insurance: Life, Health (Mutual)                   9
# Airlines                                           8
# Computers, Office Equipment                        8
# Diversified Financials                             8
# Chemicals                                          7
# Food Production                                    7
# General Merchandisers                              7
# Real estate                                        6
# Mail, Package, and Freight Delivery                6
# Internet Services and Retailing                    6
# Health Care: Insurance and Managed Care            6
# Wholesalers: Health Care                           6
# Information Technology Services                    5
# Food Consumer Products                             5
# Semiconductors and Other Electronic Components     5
# Network and Other Communications Equipment         4
# Building Materials, Glass                          4
# Food Services                                      3
# Beverages                                          3
# Wholesalers: Electronics and Office Equipment      3
# Pipelines                                          3
# Railroads                                          3
# Household and Personal Products                    3
# Wholesalers: Food and Grocery                      3
# Entertainment                                      3
# Computer Software                                  3
# Health Care: Pharmacy and Other Services           2
# Apparel                                            2
# Construction and Farm Machinery                    2
# Textiles                                           2
# Insurance: Property and Casualty (Mutual)          2
# Shipping                                           2
# Health Care: Medical Facilities                    2
# Medical Products and Equipment                     2
# Temporary Help                                     2
# Wholesalers: Diversified                           1
# Miscellaneous                                      1
# Tobacco                                            1
# Oil & Gas Equipment Services                       1
# Travel Services                                    1
# Name: industry, dtype: int64

# %% [markdown]
# # DataFrame Data Exploration Methods

# %% [markdown]
# ![slika](images/axis_param.svg)

# %%
f500.max()
# Out:
# rank                                             500
# revenues                                      485873
# revenue_change                                 442.3
# profits                                      45687.0
# assets                                       3473238
# profit_change                                 8909.5
# ceo                                       Zhou Qiang
# industry                    Wholesalers: Health Care
# sector                                   Wholesalers
# previous_rank                                    500
# country                                    Venezuela
# hq_location                      Zurich, Switzerland
# website                        http://www.zurich.com
# years_on_global_500_list                          23
# employees                                    2300000
# total_stockholder_equity                      301893
# dtype: object

# %%
f500.max(axis="index")
# Out:
# rank                                             500
# revenues                                      485873
# revenue_change                                 442.3
# profits                                      45687.0
# assets                                       3473238
# profit_change                                 8909.5
# ceo                                       Zhou Qiang
# industry                    Wholesalers: Health Care
# sector                                   Wholesalers
# previous_rank                                    500
# country                                    Venezuela
# hq_location                      Zurich, Switzerland
# website                        http://www.zurich.com
# years_on_global_500_list                          23
# employees                                    2300000
# total_stockholder_equity                      301893
# dtype: object

# %%
f500.max(axis=0)
# Out:
# rank                                             500
# revenues                                      485873
# revenue_change                                 442.3
# profits                                      45687.0
# assets                                       3473238
# profit_change                                 8909.5
# ceo                                       Zhou Qiang
# industry                    Wholesalers: Health Care
# sector                                   Wholesalers
# previous_rank                                    500
# country                                    Venezuela
# hq_location                      Zurich, Switzerland
# website                        http://www.zurich.com
# years_on_global_500_list                          23
# employees                                    2300000
# total_stockholder_equity                      301893
# dtype: object

# %%
f500.max(axis=1)
# Out:
# C:\Users\ygreg\AppData\Local\Temp\ipykernel_3384\1312660346.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   f500.max(axis=1)
# company
# Walmart                           2300000.0
# State Grid                         926067.0
# Sinopec Group                      713288.0
# China National Petroleum          1512048.0
# Toyota Motor                       437575.0
#                                     ...
# Teva Pharmaceutical Industries      92890.0
# New China Life Insurance           100609.0
# Wm. Morrison Supermarkets           77210.0
# TUI                                 66779.0
# AutoNation                          26000.0
# Length: 500, dtype: float64

# %%
f500.max(axis="columns")
# Out:
# C:\Users\ygreg\AppData\Local\Temp\ipykernel_3384\1048959413.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   f500.max(axis="columns")
# company
# Walmart                           2300000.0
# State Grid                         926067.0
# Sinopec Group                      713288.0
# China National Petroleum          1512048.0
# Toyota Motor                       437575.0
#                                     ...
# Teva Pharmaceutical Industries      92890.0
# New China Life Insurance           100609.0
# Wm. Morrison Supermarkets           77210.0
# TUI                                 66779.0
# AutoNation                          26000.0
# Length: 500, dtype: float64

# %%
f500.max(axis="index", numeric_only=True)
# Out:
# rank                            500.0
# revenues                     485873.0
# revenue_change                  442.3
# profits                       45687.0
# assets                      3473238.0
# profit_change                  8909.5
# previous_rank                   500.0
# years_on_global_500_list         23.0
# employees                   2300000.0
# total_stockholder_equity     301893.0
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## DataFrame Describe

# %%
f500.describe()
# Out:
#              rank       revenues  revenue_change       profits        assets  \
# count  500.000000     500.000000      498.000000    499.000000  5.000000e+02
# mean   250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std    144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min      1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%    125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%    250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%    375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max    500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#        profit_change  previous_rank  years_on_global_500_list     employees  \
# count     436.000000     500.000000                500.000000  5.000000e+02
# mean       24.152752     222.134000                 15.036000  1.339983e+05
# std       437.509566     146.941961                  7.932752  1.700878e+05
# min      -793.700000       0.000000                  1.000000  3.280000e+02
# 25%       -22.775000      92.750000                  7.000000  4.293250e+04
# 50%        -0.350000     219.500000                 17.000000  9.291050e+04
# 75%        17.700000     347.250000                 23.000000  1.689172e+05
# max      8909.500000     500.000000                 23.000000  2.300000e+06
#
#        total_stockholder_equity
# count                500.000000
# mean               30628.076000
# std                43642.576833
# min               -59909.000000
# 25%                 7553.750000
# 50%                15809.500000
# 75%                37828.500000
# max               301893.000000

# %%
f500.describe(include="all")
# Out:
#               rank       revenues  revenue_change       profits        assets  \
# count   500.000000     500.000000      498.000000    499.000000  5.000000e+02
# unique         NaN            NaN             NaN           NaN           NaN
# top            NaN            NaN             NaN           NaN           NaN
# freq           NaN            NaN             NaN           NaN           NaN
# mean    250.500000   55416.358000        4.538353   3055.203206  2.436323e+05
# std     144.481833   45725.478963       28.549067   5171.981071  4.851937e+05
# min       1.000000   21609.000000      -67.300000 -13038.000000  3.717000e+03
# 25%     125.750000   29003.000000       -5.900000    556.950000  3.658850e+04
# 50%     250.500000   40236.000000        0.550000   1761.600000  7.326150e+04
# 75%     375.250000   63926.750000        6.975000   3954.000000  1.805640e+05
# max     500.000000  485873.000000      442.300000  45687.000000  3.473238e+06
#
#         profit_change                  ceo                       industry  \
# count      436.000000                  500                            500
# unique            NaN                  500                             58
# top               NaN  C. Douglas McMillon  Banks: Commercial and Savings
# freq              NaN                    1                             51
# mean        24.152752                  NaN                            NaN
# std        437.509566                  NaN                            NaN
# min       -793.700000                  NaN                            NaN
# 25%        -22.775000                  NaN                            NaN
# 50%         -0.350000                  NaN                            NaN
# 75%         17.700000                  NaN                            NaN
# max       8909.500000                  NaN                            NaN
#
#             sector  previous_rank country     hq_location  \
# count          500     500.000000     500             500
# unique          21            NaN      34             235
# top     Financials            NaN     USA  Beijing, China
# freq           118            NaN     132              56
# mean           NaN     222.134000     NaN             NaN
# std            NaN     146.941961     NaN             NaN
# min            NaN       0.000000     NaN             NaN
# 25%            NaN      92.750000     NaN             NaN
# 50%            NaN     219.500000     NaN             NaN
# 75%            NaN     347.250000     NaN             NaN
# max            NaN     500.000000     NaN             NaN
#
#                        website  years_on_global_500_list     employees  \
# count                      500                500.000000  5.000000e+02
# unique                     500                       NaN           NaN
# top     http://www.walmart.com                       NaN           NaN
# freq                         1                       NaN           NaN
# mean                       NaN                 15.036000  1.339983e+05
# std                        NaN                  7.932752  1.700878e+05
# min                        NaN                  1.000000  3.280000e+02
# 25%                        NaN                  7.000000  4.293250e+04
# 50%                        NaN                 17.000000  9.291050e+04
# 75%                        NaN                 23.000000  1.689172e+05
# max                        NaN                 23.000000  2.300000e+06
#
#         total_stockholder_equity
# count                 500.000000
# unique                       NaN
# top                          NaN
# freq                         NaN
# mean                30628.076000
# std                 43642.576833
# min                -59909.000000
# 25%                  7553.750000
# 50%                 15809.500000
# 75%                 37828.500000
# max                301893.000000

# %%
f500.describe(include=["O"])
# Out:
#                         ceo                       industry      sector  \
# count                   500                            500         500
# unique                  500                             58          21
# top     C. Douglas McMillon  Banks: Commercial and Savings  Financials
# freq                      1                             51         118
#
#        country     hq_location                 website
# count      500             500                     500
# unique      34             235                     500
# top        USA  Beijing, China  http://www.walmart.com
# freq       132              56                       1

# %% [markdown]
# ---

# %% [markdown]
# # Changing values

# %%
data = f500[["rank", "profits"]].copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   rank     500 non-null    int16
#  1   profits  499 non-null    float64
# dtypes: float64(1), int16(1)
# memory usage: 25.0+ KB

# %%
data["profits"] = 0.0
data
# Out:
#                                 rank  profits
# company
# Walmart                            1      0.0
# State Grid                         2      0.0
# Sinopec Group                      3      0.0
# China National Petroleum           4      0.0
# Toyota Motor                       5      0.0
# ...                              ...      ...
# Teva Pharmaceutical Industries   496      0.0
# New China Life Insurance         497      0.0
# Wm. Morrison Supermarkets        498      0.0
# TUI                              499      0.0
# AutoNation                       500      0.0
#
# [500 rows x 2 columns]

# %% [markdown]
# # Boolean Indexing pandas objects

# %%
d = {"name": ["Jaka", "Eva", "Sara", "Miha"], 
    "age": [12, 8, 5, 8]}
df = pd.DataFrame(d, index=["w", "x", "y", "z"])
df
# Out:
#    name  age
# w  Jaka   12
# x   Eva    8
# y  Sara    5
# z  Miha    8

# %%
bool_array = df["age"] == 8
print(type(bool_array))
bool_array
# Out:
# <class 'pandas.core.series.Series'>
# w    False
# x     True
# y    False
# z     True
# Name: age, dtype: bool

# %%
result = df[bool_array]
print(type(result))
result
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    name  age
# x   Eva    8
# z  Miha    8

# %%
df.loc[bool_array, "name"]
# Out:
# x     Eva
# z    Miha
# Name: name, dtype: object

# %% [markdown]
# ---

# %%
data = f500.copy()
data.head()
# Out:
#                           rank  revenues  revenue_change  profits  assets  \
# company
# Walmart                      1    485873             0.8  13643.0  198825
# State Grid                   2    315199            -4.4   9571.3  489838
# Sinopec Group                3    267518            -9.1   1257.9  310726
# China National Petroleum     4    262573           -12.3   1867.5  585619
# Toyota Motor                 5    254694             7.7  16899.3  437575
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                               1     USA  Bentonville, AR
# State Grid                            2   China   Beijing, China
# Sinopec Group                         4   China   Beijing, China
# China National Petroleum              3   China   Beijing, China
# Toyota Motor                          8   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                         23    2300000
# State Grid                                      17     926067
# Sinopec Group                                   19     713288
# China National Petroleum                        17    1512048
# Toyota Motor                                    23     364445
#
#                           total_stockholder_equity
# company
# Walmart                                      77798
# State Grid                                  209456
# Sinopec Group                               106523
# China National Petroleum                    301893
# Toyota Motor                                157210

# %%
filter_ = data["previous_rank"] == 0
data[filter_].head()
# Out:
#                         rank  revenues  revenue_change  profits  assets  \
# company
# Legal & General Group     49    105235           442.3   1697.9  577954
# Uniper                    91     74407             NaN  -3557.5   51541
# Dell Technologies        124     64806            18.1  -1672.0  118206
# Anbang Insurance Group   139     60800           124.0   3883.9  430040
# Albertsons Cos.          141     59678             1.6   -373.3   23755
#
#                         profit_change               ceo  \
# company
# Legal & General Group             3.4      Nigel Wilson
# Uniper                            NaN     Klaus Schafer
# Dell Technologies                 NaN   Michael S. Dell
# Anbang Insurance Group            0.9        Wu Xiaohui
# Albertsons Cos.                   NaN  Robert G. Miller
#
#                                                 industry              sector  \
# company
# Legal & General Group    Insurance: Life, Health (stock)          Financials
# Uniper                                            Energy              Energy
# Dell Technologies            Computers, Office Equipment          Technology
# Anbang Insurance Group  Insurance: Life, Health (Mutual)          Financials
# Albertsons Cos.                     Food and Drug Stores  Food & Drug Stores
#
#                         previous_rank  country          hq_location  \
# company
# Legal & General Group               0  Britain      London, Britain
# Uniper                              0  Germany  Dusseldorf, Germany
# Dell Technologies                   0      USA       Round Rock, TX
# Anbang Insurance Group              0    China       Beijing, China
# Albertsons Cos.                     0      USA            Boise, ID
#
#                                                     website  \
# company
# Legal & General Group   http://www.legalandgeneralgroup.com
# Uniper                             http://www.uniper.energy
# Dell Technologies           http://www.delltechnologies.com
# Anbang Insurance Group           http://www.anbanggroup.com
# Albertsons Cos.                   http://www.albertsons.com
#
#                         years_on_global_500_list  employees  \
# company
# Legal & General Group                         17       8939
# Uniper                                         1      12890
# Dell Technologies                             17     138000
# Anbang Insurance Group                         1      40707
# Albertsons Cos.                               13     273000
#
#                         total_stockholder_equity
# company
# Legal & General Group                       8579
# Uniper                                     12889
# Dell Technologies                          13243
# Anbang Insurance Group                     20372
# Albertsons Cos.                             1371

# %%
data.loc[filter_, "previous_rank"] = np.nan
data[filter_].head()
# Out:
#                         rank  revenues  revenue_change  profits  assets  \
# company
# Legal & General Group     49    105235           442.3   1697.9  577954
# Uniper                    91     74407             NaN  -3557.5   51541
# Dell Technologies        124     64806            18.1  -1672.0  118206
# Anbang Insurance Group   139     60800           124.0   3883.9  430040
# Albertsons Cos.          141     59678             1.6   -373.3   23755
#
#                         profit_change               ceo  \
# company
# Legal & General Group             3.4      Nigel Wilson
# Uniper                            NaN     Klaus Schafer
# Dell Technologies                 NaN   Michael S. Dell
# Anbang Insurance Group            0.9        Wu Xiaohui
# Albertsons Cos.                   NaN  Robert G. Miller
#
#                                                 industry              sector  \
# company
# Legal & General Group    Insurance: Life, Health (stock)          Financials
# Uniper                                            Energy              Energy
# Dell Technologies            Computers, Office Equipment          Technology
# Anbang Insurance Group  Insurance: Life, Health (Mutual)          Financials
# Albertsons Cos.                     Food and Drug Stores  Food & Drug Stores
#
#                         previous_rank  country          hq_location  \
# company
# Legal & General Group             NaN  Britain      London, Britain
# Uniper                            NaN  Germany  Dusseldorf, Germany
# Dell Technologies                 NaN      USA       Round Rock, TX
# Anbang Insurance Group            NaN    China       Beijing, China
# Albertsons Cos.                   NaN      USA            Boise, ID
#
#                                                     website  \
# company
# Legal & General Group   http://www.legalandgeneralgroup.com
# Uniper                             http://www.uniper.energy
# Dell Technologies           http://www.delltechnologies.com
# Anbang Insurance Group           http://www.anbanggroup.com
# Albertsons Cos.                   http://www.albertsons.com
#
#                         years_on_global_500_list  employees  \
# company
# Legal & General Group                         17       8939
# Uniper                                         1      12890
# Dell Technologies                             17     138000
# Anbang Insurance Group                         1      40707
# Albertsons Cos.                               13     273000
#
#                         total_stockholder_equity
# company
# Legal & General Group                       8579
# Uniper                                     12889
# Dell Technologies                          13243
# Anbang Insurance Group                     20372
# Albertsons Cos.                             1371

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 500 entries, Walmart to AutoNation
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   rank                      500 non-null    int16
#  1   revenues                  500 non-null    int64
#  2   revenue_change            498 non-null    float64
#  3   profits                   499 non-null    float64
#  4   assets                    500 non-null    int64
#  5   profit_change             436 non-null    float64
#  6   ceo                       500 non-null    object
#  7   industry                  500 non-null    object
#  8   sector                    500 non-null    object
#  9   previous_rank             467 non-null    float64
#  10  country                   500 non-null    object
#  11  hq_location               500 non-null    object
#  12  website                   500 non-null    object
#  13  years_on_global_500_list  500 non-null    int64
#  14  employees                 500 non-null    int64
#  15  total_stockholder_equity  500 non-null    int64
# dtypes: float64(4), int16(1), int64(5), object(6)
# memory usage: 79.6+ KB

# %%
f500[ f500["previous_rank"] == 0 ] = np.nan
f500["previous_rank"]
# Out:
# company
# Walmart                             1.0
# State Grid                          2.0
# Sinopec Group                       4.0
# China National Petroleum            3.0
# Toyota Motor                        8.0
#                                   ...
# Teva Pharmaceutical Industries      NaN
# New China Life Insurance          427.0
# Wm. Morrison Supermarkets         437.0
# TUI                               467.0
# AutoNation                          NaN
# Name: previous_rank, Length: 500, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# # Adding data

# %%
df = pd.DataFrame({"a": [1,2,3], "b": [4,5,6]})
df
# Out:
#    a  b
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df["c"] = 5
df
# Out:
#    a  b  c
# 0  1  4  5
# 1  2  5  5
# 2  3  6  5

# %%
df["d"] = [9,8,7]
df
# Out:
#    a  b  c  d
# 0  1  4  5  9
# 1  2  5  5  8
# 2  3  6  5  7

# %%
df["e"] = [1,2]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [286], line 1
# ----> 1 df["e"] = [1,2]
#       2 df
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3978, in DataFrame.__setitem__(self, key, value)
#    3975     self._setitem_array([key], value)
#    3976 else:
#    3977     # set column
# -> 3978     self._set_item(key, value)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4172, in DataFrame._set_item(self, key, value)
#    4162 def _set_item(self, key, value) -> None:
#    4163     """
#    4164     Add series to DataFrame in specified column.
#    4165
#    (...)
#    4170     ensure homogeneity.
#    4171     """
# -> 4172     value = self._sanitize_column(value)
#    4174     if (
#    4175         key in self.columns
#    4176         and value.ndim == 1
#    4177         and not is_extension_array_dtype(value)
#    4178     ):
#    4179         # broadcast across multiple columns if necessary
#    4180         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4912, in DataFrame._sanitize_column(self, value)
#    4909     return _reindex_for_setitem(Series(value), self.index)
#    4911 if is_list_like(value):
# -> 4912     com.require_length_match(value, self.index)
#    4913 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2) does not match length of index (3)

# %%
f500["rank_change"] = f500["previous_rank"] - f500["rank"]
f500.head()
# Out:
#                           rank  revenues  revenue_change  profits    assets  \
# company
# Walmart                    1.0  485873.0             0.8  13643.0  198825.0
# State Grid                 2.0  315199.0            -4.4   9571.3  489838.0
# Sinopec Group              3.0  267518.0            -9.1   1257.9  310726.0
# China National Petroleum   4.0  262573.0           -12.3   1867.5  585619.0
# Toyota Motor               5.0  254694.0             7.7  16899.3  437575.0
#
#                           profit_change                  ceo  \
# company
# Walmart                            -7.2  C. Douglas McMillon
# State Grid                         -6.2              Kou Wei
# Sinopec Group                     -65.0            Wang Yupu
# China National Petroleum          -73.7        Zhang Jianhua
# Toyota Motor                      -12.3          Akio Toyoda
#
#                                           industry                  sector  \
# company
# Walmart                      General Merchandisers               Retailing
# State Grid                               Utilities                  Energy
# Sinopec Group                   Petroleum Refining                  Energy
# China National Petroleum        Petroleum Refining                  Energy
# Toyota Motor              Motor Vehicles and Parts  Motor Vehicles & Parts
#
#                           previous_rank country      hq_location  \
# company
# Walmart                             1.0     USA  Bentonville, AR
# State Grid                          2.0   China   Beijing, China
# Sinopec Group                       4.0   China   Beijing, China
# China National Petroleum            3.0   China   Beijing, China
# Toyota Motor                        8.0   Japan    Toyota, Japan
#
#                                                website  \
# company
# Walmart                         http://www.walmart.com
# State Grid                      http://www.sgcc.com.cn
# Sinopec Group                   http://www.sinopec.com
# China National Petroleum        http://www.cnpc.com.cn
# Toyota Motor              http://www.toyota-global.com
#
#                           years_on_global_500_list  employees  \
# company
# Walmart                                       23.0  2300000.0
# State Grid                                    17.0   926067.0
# Sinopec Group                                 19.0   713288.0
# China National Petroleum                      17.0  1512048.0
# Toyota Motor                                  23.0   364445.0
#
#                           total_stockholder_equity  rank_change
# company
# Walmart                                    77798.0          0.0
# State Grid                                209456.0          0.0
# Sinopec Group                             106523.0          1.0
# China National Petroleum                  301893.0         -1.0
# Toyota Motor                              157210.0          3.0

# %%
f500["rank_change"].describe()
# Out:
# count    467.000000
# mean      -3.533191
# std       44.293603
# min     -199.000000
# 25%      -21.000000
# 50%       -2.000000
# 75%       10.000000
# max      226.000000
# Name: rank_change, dtype: float64

# %% [markdown]
# ---

# %%
f500["country"].value_counts().head(2)
# Out:
# USA      122
# China     99
# Name: country, dtype: int64

# %%
usa_filter = f500["country"] == "USA"
usa =f500[usa_filter]
usa["sector"].value_counts().head(3)
# Out:
# Financials     25
# Health Care    15
# Energy         13
# Name: sector, dtype: int64

# %%
china_filter = f500["country"] == "China"
china = f500[china_filter]
china["sector"].value_counts().head(3)
# Out:
# Energy                        22
# Financials                    22
# Engineering & Construction     8
# Name: sector, dtype: int64

# %%
f500[f500["country"] == "Slovenia"]
# Out:
# Empty DataFrame
# Columns: [rank, revenues, revenue_change, profits, assets, profit_change, ceo, industry, sector, previous_rank, country, hq_location, website, years_on_global_500_list, employees, total_stockholder_equity, rank_change]
# Index: []

# %% [markdown]
# ---

# %% [markdown]
# ## Deleting Data

# %%
data = {
    "a": [1,2,3,4],
    "b": [4,3,2,1],
    "c": [5,6,7,8]
}
df = pd.DataFrame(data, index=["w", "x", "y", "z"])
df
# Out:
#    a  b  c
# w  1  4  5
# x  2  3  6
# y  3  2  7
# z  4  1  8

# %%
df.drop("x")
# Out:
#    a  b  c
# w  1  4  5
# y  3  2  7
# z  4  1  8

# %%
df.drop(labels=["a"], axis=1)
# Out:
#    b  c
# w  4  5
# x  3  6
# y  2  7
# z  1  8

# %%
df.drop(labels=["a", "c"], axis=1)
# Out:
#    b
# w  4
# x  3
# y  2
# z  1

# %%
df.drop(labels=["w", "y"])
# Out:
#    a  b  c
# x  2  3  6
# z  4  1  8

# %%
df.drop(index=["x", "y"])
# Out:
#    a  b  c
# w  1  4  5
# z  4  1  8

# %%
df.drop(columns=["a", "c"])
# Out:
#    b
# w  4
# x  3
# y  2
# z  1

# %%
df
# Out:
#    a  b  c
# w  1  4  5
# x  2  3  6
# y  3  2  7
# z  4  1  8

# %%
new_df = df.drop(columns=["a", "c"])
new_df
# Out:
#    b
# w  4
# x  3
# y  2
# z  1

# %%
print(df)

df.drop(columns=["a", "c"], inplace=True)
df
# Out:
#    a  b  c
# w  1  4  5
# x  2  3  6
# y  3  2  7
# z  4  1  8
#    b
# w  4
# x  3
# y  2
# z  1

# %% [markdown]
# ---

# %% [markdown]
# ## Multiple filters

# %%
filter_1 = f500["sector"] == "Technology"
f500[filter_1].head()
# Out:
#                             rank  revenues  revenue_change  profits    assets  \
# company
# Apple                        9.0  215639.0            -7.7  45687.0  321686.0
# Samsung Electronics         15.0  173957.0            -2.0  19316.5  217104.0
# Amazon.com                  26.0  135987.0            27.1   2371.0   83402.0
# Hon Hai Precision Industry  27.0  135129.0            -4.3   4608.8   80436.0
# Alphabet                    65.0   90272.0            20.4  19478.0  167497.0
#
#                             profit_change               ceo  \
# company
# Apple                               -14.4   Timothy D. Cook
# Samsung Electronics                  16.8      Oh-Hyun Kwon
# Amazon.com                          297.8  Jeffrey P. Bezos
# Hon Hai Precision Industry           -0.4         Terry Gou
# Alphabet                             19.1        Larry Page
#
#                                                    industry      sector  \
# company
# Apple                           Computers, Office Equipment  Technology
# Samsung Electronics          Electronics, Electrical Equip.  Technology
# Amazon.com                  Internet Services and Retailing  Technology
# Hon Hai Precision Industry   Electronics, Electrical Equip.  Technology
# Alphabet                    Internet Services and Retailing  Technology
#
#                             previous_rank      country  \
# company
# Apple                                 9.0          USA
# Samsung Electronics                  13.0  South Korea
# Amazon.com                           44.0          USA
# Hon Hai Precision Industry           25.0       Taiwan
# Alphabet                             94.0          USA
#
#                                         hq_location                 website  \
# company
# Apple                                 Cupertino, CA    http://www.apple.com
# Samsung Electronics              Suwon, South Korea  http://www.samsung.com
# Amazon.com                              Seattle, WA   http://www.amazon.com
# Hon Hai Precision Industry  New Taipei City, Taiwan  http://www.foxconn.com
# Alphabet                          Mountain View, CA      http://www.abc.xyz
#
#                             years_on_global_500_list  employees  \
# company
# Apple                                           15.0   116000.0
# Samsung Electronics                             23.0   325000.0
# Amazon.com                                       9.0   341400.0
# Hon Hai Precision Industry                      13.0   726772.0
# Alphabet                                         9.0    72053.0
#
#                             total_stockholder_equity  rank_change
# company
# Apple                                       128249.0          0.0
# Samsung Electronics                         154376.0         -2.0
# Amazon.com                                   19285.0         18.0
# Hon Hai Precision Industry                   33476.0         -2.0
# Alphabet                                    139036.0         29.0

# %%
filter_2 = f500["profits"] > 10_000
f500[filter_2].head()
# Out:
#                      rank  revenues  revenue_change  profits    assets  \
# company
# Walmart               1.0  485873.0             0.8  13643.0  198825.0
# Toyota Motor          5.0  254694.0             7.7  16899.3  437575.0
# Berkshire Hathaway    8.0  223604.0             6.1  24074.0  620854.0
# Apple                 9.0  215639.0            -7.7  45687.0  321686.0
# Samsung Electronics  15.0  173957.0            -2.0  19316.5  217104.0
#
#                      profit_change                  ceo  \
# company
# Walmart                       -7.2  C. Douglas McMillon
# Toyota Motor                 -12.3          Akio Toyoda
# Berkshire Hathaway             NaN    Warren E. Buffett
# Apple                        -14.4      Timothy D. Cook
# Samsung Electronics           16.8         Oh-Hyun Kwon
#
#                                                      industry  \
# company
# Walmart                                 General Merchandisers
# Toyota Motor                         Motor Vehicles and Parts
# Berkshire Hathaway   Insurance: Property and Casualty (Stock)
# Apple                             Computers, Office Equipment
# Samsung Electronics            Electronics, Electrical Equip.
#
#                                      sector  previous_rank      country  \
# company
# Walmart                           Retailing            1.0          USA
# Toyota Motor         Motor Vehicles & Parts            8.0        Japan
# Berkshire Hathaway               Financials           11.0          USA
# Apple                            Technology            9.0          USA
# Samsung Electronics              Technology           13.0  South Korea
#
#                             hq_location                           website  \
# company
# Walmart                 Bentonville, AR            http://www.walmart.com
# Toyota Motor              Toyota, Japan      http://www.toyota-global.com
# Berkshire Hathaway            Omaha, NE  http://www.berkshirehathaway.com
# Apple                     Cupertino, CA              http://www.apple.com
# Samsung Electronics  Suwon, South Korea            http://www.samsung.com
#
#                      years_on_global_500_list  employees  \
# company
# Walmart                                  23.0  2300000.0
# Toyota Motor                             23.0   364445.0
# Berkshire Hathaway                       21.0   367700.0
# Apple                                    15.0   116000.0
# Samsung Electronics                      23.0   325000.0
#
#                      total_stockholder_equity  rank_change
# company
# Walmart                               77798.0          0.0
# Toyota Motor                         157210.0          3.0
# Berkshire Hathaway                   283001.0          3.0
# Apple                                128249.0          0.0
# Samsung Electronics                  154376.0         -2.0

# %%
filter_ = filter_1 & filter_2
f500[filter_]
# Out:
#                                      rank  revenues  revenue_change  profits  \
# company
# Apple                                 9.0  215639.0            -7.7  45687.0
# Samsung Electronics                  15.0  173957.0            -2.0  19316.5
# Alphabet                             65.0   90272.0            20.4  19478.0
# Microsoft                            69.0   85320.0            -8.8  16798.0
# IBM                                  81.0   79919.0            -3.1  11872.0
# Intel                               144.0   59387.0             7.3  10316.0
# Cisco Systems                       187.0   49247.0             0.2  10739.0
# Taiwan Semiconductor Manufacturing  369.0   29388.0            10.6  10283.7
#
#                                       assets  profit_change  \
# company
# Apple                               321686.0          -14.4
# Samsung Electronics                 217104.0           16.8
# Alphabet                            167497.0           19.1
# Microsoft                           193694.0           37.8
# IBM                                 117470.0          -10.0
# Intel                               113327.0           -9.7
# Cisco Systems                       121652.0           19.6
# Taiwan Semiconductor Manufacturing   58535.0            7.8
#
#                                                     ceo  \
# company
# Apple                                   Timothy D. Cook
# Samsung Electronics                        Oh-Hyun Kwon
# Alphabet                                     Larry Page
# Microsoft                                 Satya Nadella
# IBM                                 Virginia M. Rometty
# Intel                                 Brian M. Krzanich
# Cisco Systems                        Charles H. Robbins
# Taiwan Semiconductor Manufacturing             Mark Liu
#
#                                                                           industry  \
# company
# Apple                                                  Computers, Office Equipment
# Samsung Electronics                                 Electronics, Electrical Equip.
# Alphabet                                           Internet Services and Retailing
# Microsoft                                                        Computer Software
# IBM                                                Information Technology Services
# Intel                               Semiconductors and Other Electronic Components
# Cisco Systems                           Network and Other Communications Equipment
# Taiwan Semiconductor Manufacturing  Semiconductors and Other Electronic Components
#
#                                         sector  previous_rank      country  \
# company
# Apple                               Technology            9.0          USA
# Samsung Electronics                 Technology           13.0  South Korea
# Alphabet                            Technology           94.0          USA
# Microsoft                           Technology           63.0          USA
# IBM                                 Technology           82.0          USA
# Intel                               Technology          158.0          USA
# Cisco Systems                       Technology          183.0          USA
# Taiwan Semiconductor Manufacturing  Technology          403.0       Taiwan
#
#                                            hq_location  \
# company
# Apple                                    Cupertino, CA
# Samsung Electronics                 Suwon, South Korea
# Alphabet                             Mountain View, CA
# Microsoft                                  Redmond, WA
# IBM                                         Armonk, NY
# Intel                                  Santa Clara, CA
# Cisco Systems                             San Jose, CA
# Taiwan Semiconductor Manufacturing     Hsinchu, Taiwan
#
#                                                      website  \
# company
# Apple                                   http://www.apple.com
# Samsung Electronics                   http://www.samsung.com
# Alphabet                                  http://www.abc.xyz
# Microsoft                           http://www.microsoft.com
# IBM                                       http://www.ibm.com
# Intel                                   http://www.intel.com
# Cisco Systems                           http://www.cisco.com
# Taiwan Semiconductor Manufacturing       http://www.tsmc.com
#
#                                     years_on_global_500_list  employees  \
# company
# Apple                                                   15.0   116000.0
# Samsung Electronics                                     23.0   325000.0
# Alphabet                                                 9.0    72053.0
# Microsoft                                               20.0   114000.0
# IBM                                                     23.0   414400.0
# Intel                                                   23.0   106000.0
# Cisco Systems                                           18.0    73700.0
# Taiwan Semiconductor Manufacturing                       3.0    46968.0
#
#                                     total_stockholder_equity  rank_change
# company
# Apple                                               128249.0          0.0
# Samsung Electronics                                 154376.0         -2.0
# Alphabet                                            139036.0         29.0
# Microsoft                                            71997.0         -6.0
# IBM                                                  18246.0          1.0
# Intel                                                66226.0         14.0
# Cisco Systems                                        63586.0         -4.0
# Taiwan Semiconductor Manufacturing                   42174.0         34.0

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>pandas</th>
# <th>Python equivalent</th>
# <th>Meaning</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><code>a &amp; b</code></td>
# <td><code>a and b</code></td>
# <td><code>True</code> if both <code>a</code> and <code>b</code> are <code>True</code>, else <code>False</code></td>
# </tr>
# <tr>
# <td><code>a | b</code></td>
# <td><code>a or b</code></td>
# <td><code>True</code> if either <code>a</code> or <code>b</code> is <code>True</code></td>
# </tr>
# <tr>
# <td><code>~a</code></td>
# <td><code>not a</code></td>
# <td><code>True</code> if <code>a</code> is <code>False</code>, else <code>False</code></td>
# </tr>
# </tbody>
# </table>

# %%
filter_ = (f500["sector"] == "Technology") & (f500["profits"] > 10_000)
f500[filter_]
# Out:
#                                      rank  revenues  revenue_change  profits  \
# company
# Apple                                 9.0  215639.0            -7.7  45687.0
# Samsung Electronics                  15.0  173957.0            -2.0  19316.5
# Alphabet                             65.0   90272.0            20.4  19478.0
# Microsoft                            69.0   85320.0            -8.8  16798.0
# IBM                                  81.0   79919.0            -3.1  11872.0
# Intel                               144.0   59387.0             7.3  10316.0
# Cisco Systems                       187.0   49247.0             0.2  10739.0
# Taiwan Semiconductor Manufacturing  369.0   29388.0            10.6  10283.7
#
#                                       assets  profit_change  \
# company
# Apple                               321686.0          -14.4
# Samsung Electronics                 217104.0           16.8
# Alphabet                            167497.0           19.1
# Microsoft                           193694.0           37.8
# IBM                                 117470.0          -10.0
# Intel                               113327.0           -9.7
# Cisco Systems                       121652.0           19.6
# Taiwan Semiconductor Manufacturing   58535.0            7.8
#
#                                                     ceo  \
# company
# Apple                                   Timothy D. Cook
# Samsung Electronics                        Oh-Hyun Kwon
# Alphabet                                     Larry Page
# Microsoft                                 Satya Nadella
# IBM                                 Virginia M. Rometty
# Intel                                 Brian M. Krzanich
# Cisco Systems                        Charles H. Robbins
# Taiwan Semiconductor Manufacturing             Mark Liu
#
#                                                                           industry  \
# company
# Apple                                                  Computers, Office Equipment
# Samsung Electronics                                 Electronics, Electrical Equip.
# Alphabet                                           Internet Services and Retailing
# Microsoft                                                        Computer Software
# IBM                                                Information Technology Services
# Intel                               Semiconductors and Other Electronic Components
# Cisco Systems                           Network and Other Communications Equipment
# Taiwan Semiconductor Manufacturing  Semiconductors and Other Electronic Components
#
#                                         sector  previous_rank      country  \
# company
# Apple                               Technology            9.0          USA
# Samsung Electronics                 Technology           13.0  South Korea
# Alphabet                            Technology           94.0          USA
# Microsoft                           Technology           63.0          USA
# IBM                                 Technology           82.0          USA
# Intel                               Technology          158.0          USA
# Cisco Systems                       Technology          183.0          USA
# Taiwan Semiconductor Manufacturing  Technology          403.0       Taiwan
#
#                                            hq_location  \
# company
# Apple                                    Cupertino, CA
# Samsung Electronics                 Suwon, South Korea
# Alphabet                             Mountain View, CA
# Microsoft                                  Redmond, WA
# IBM                                         Armonk, NY
# Intel                                  Santa Clara, CA
# Cisco Systems                             San Jose, CA
# Taiwan Semiconductor Manufacturing     Hsinchu, Taiwan
#
#                                                      website  \
# company
# Apple                                   http://www.apple.com
# Samsung Electronics                   http://www.samsung.com
# Alphabet                                  http://www.abc.xyz
# Microsoft                           http://www.microsoft.com
# IBM                                       http://www.ibm.com
# Intel                                   http://www.intel.com
# Cisco Systems                           http://www.cisco.com
# Taiwan Semiconductor Manufacturing       http://www.tsmc.com
#
#                                     years_on_global_500_list  employees  \
# company
# Apple                                                   15.0   116000.0
# Samsung Electronics                                     23.0   325000.0
# Alphabet                                                 9.0    72053.0
# Microsoft                                               20.0   114000.0
# IBM                                                     23.0   414400.0
# Intel                                                   23.0   106000.0
# Cisco Systems                                           18.0    73700.0
# Taiwan Semiconductor Manufacturing                       3.0    46968.0
#
#                                     total_stockholder_equity  rank_change
# company
# Apple                                               128249.0          0.0
# Samsung Electronics                                 154376.0         -2.0
# Alphabet                                            139036.0         29.0
# Microsoft                                            71997.0         -6.0
# IBM                                                  18246.0          1.0
# Intel                                                66226.0         14.0
# Cisco Systems                                        63586.0         -4.0
# Taiwan Semiconductor Manufacturing                   42174.0         34.0

# %%
filter_ = (f500["sector"] == "Technology") & (f500["country"] != "USA")
f500[filter_].head()
# Out:
#                               rank  revenues  revenue_change  profits  \
# company
# Samsung Electronics           15.0  173957.0            -2.0  19316.5
# Hon Hai Precision Industry    27.0  135129.0            -4.3   4608.8
# Hitachi                       71.0   84558.0             1.2   2134.3
# Huawei Investment & Holding   83.0   78511.0            24.9   5579.4
# Sony                         105.0   70170.0             3.9    676.4
#
#                                assets  profit_change                   ceo  \
# company
# Samsung Electronics          217104.0           16.8          Oh-Hyun Kwon
# Hon Hai Precision Industry    80436.0           -0.4             Terry Gou
# Hitachi                       86742.0           48.8  Toshiaki Higashihara
# Huawei Investment & Holding   63837.0           -5.0          Ren Zhengfei
# Sony                         158519.0          -45.1           Kazuo Hirai
#
#                                                                industry  \
# company
# Samsung Electronics                      Electronics, Electrical Equip.
# Hon Hai Precision Industry               Electronics, Electrical Equip.
# Hitachi                                  Electronics, Electrical Equip.
# Huawei Investment & Holding  Network and Other Communications Equipment
# Sony                                     Electronics, Electrical Equip.
#
#                                  sector  previous_rank      country  \
# company
# Samsung Electronics          Technology           13.0  South Korea
# Hon Hai Precision Industry   Technology           25.0       Taiwan
# Hitachi                      Technology           79.0        Japan
# Huawei Investment & Holding  Technology          129.0        China
# Sony                         Technology          113.0        Japan
#
#                                          hq_location                 website  \
# company
# Samsung Electronics               Suwon, South Korea  http://www.samsung.com
# Hon Hai Precision Industry   New Taipei City, Taiwan  http://www.foxconn.com
# Hitachi                                 Tokyo, Japan  http://www.hitachi.com
# Huawei Investment & Holding          Shenzhen, China   http://www.huawei.com
# Sony                                    Tokyo, Japan     http://www.sony.net
#
#                              years_on_global_500_list  employees  \
# company
# Samsung Electronics                              23.0   325000.0
# Hon Hai Precision Industry                       13.0   726772.0
# Hitachi                                          23.0   303887.0
# Huawei Investment & Holding                       8.0   180000.0
# Sony                                             23.0   128400.0
#
#                              total_stockholder_equity  rank_change
# company
# Samsung Electronics                          154376.0         -2.0
# Hon Hai Precision Industry                    33476.0         -2.0
# Hitachi                                       26632.0          8.0
# Huawei Investment & Holding                   20159.0         46.0
# Sony                                          22415.0          8.0

# %% [markdown]
# ---

# %% [markdown]
# # Sorting

# %%
filter_ = f500["country"] == "China"
china = f500[filter_]
china.head()
# Out:
#                                        rank  revenues  revenue_change  \
# company
# State Grid                              2.0  315199.0            -4.4
# Sinopec Group                           3.0  267518.0            -9.1
# China National Petroleum                4.0  262573.0           -12.3
# Industrial & Commercial Bank of China  22.0  147675.0           -11.7
# China State Construction Engineering   24.0  144505.0             3.1
#
#                                        profits     assets  profit_change  \
# company
# State Grid                              9571.3   489838.0           -6.2
# Sinopec Group                           1257.9   310726.0          -65.0
# China National Petroleum                1867.5   585619.0          -73.7
# Industrial & Commercial Bank of China  41883.9  3473238.0           -5.0
# China State Construction Engineering    2492.9   201269.0           10.7
#
#                                                  ceo  \
# company
# State Grid                                   Kou Wei
# Sinopec Group                              Wang Yupu
# China National Petroleum               Zhang Jianhua
# Industrial & Commercial Bank of China         Gu Shu
# China State Construction Engineering       Guan Qing
#
#                                                             industry  \
# company
# State Grid                                                 Utilities
# Sinopec Group                                     Petroleum Refining
# China National Petroleum                          Petroleum Refining
# Industrial & Commercial Bank of China  Banks: Commercial and Savings
# China State Construction Engineering       Engineering, Construction
#
#                                                            sector  \
# company
# State Grid                                                 Energy
# Sinopec Group                                              Energy
# China National Petroleum                                   Energy
# Industrial & Commercial Bank of China                  Financials
# China State Construction Engineering   Engineering & Construction
#
#                                        previous_rank country     hq_location  \
# company
# State Grid                                       2.0   China  Beijing, China
# Sinopec Group                                    4.0   China  Beijing, China
# China National Petroleum                         3.0   China  Beijing, China
# Industrial & Commercial Bank of China           15.0   China  Beijing, China
# China State Construction Engineering            27.0   China  Beijing, China
#
#                                                        website  \
# company
# State Grid                              http://www.sgcc.com.cn
# Sinopec Group                           http://www.sinopec.com
# China National Petroleum                http://www.cnpc.com.cn
# Industrial & Commercial Bank of China  http://www.icbc-ltd.com
# China State Construction Engineering      http://www.cscec.com
#
#                                        years_on_global_500_list  employees  \
# company
# State Grid                                                 17.0   926067.0
# Sinopec Group                                              19.0   713288.0
# China National Petroleum                                   17.0  1512048.0
# Industrial & Commercial Bank of China                      19.0   461749.0
# China State Construction Engineering                        6.0   263915.0
#
#                                        total_stockholder_equity  rank_change
# company
# State Grid                                             209456.0          0.0
# Sinopec Group                                          106523.0          1.0
# China National Petroleum                               301893.0         -1.0
# Industrial & Commercial Bank of China                  283438.0         -7.0
# China State Construction Engineering                    15344.0          3.0

# %%
sorted_china = china.sort_values("employees", ascending=False)
sorted_china.iloc[0, 14]
# Out:
# 1512048.0

# %% [markdown]
# ---

# %% [markdown]
# <div class="alert alert-block alert-info not_clean">
# <b>Vaja:</b>
#
#
# V datasetu ustvarite nov stolpec `roa`. V stolpcu naj bod vrednost **ROA - Return on Assets** za vsako podjetje.
#
#     roa = profits / assets
#
# ROA je metrika, ki nam pove koliko dobička lahko podjetje ustvari s svojimi sredstvi.
#
# Nato za vsako državo izračunajte koliko je povprečni ROA. Vse možne države, ki se pojavijo v stolpcu `country` lahko pridobite s pomočjo `Series.unique()` metode, ki vrne vse unikatne vrednosti v stolpcu.
# </div>

# %% [markdown]
# ```python
# OUTPUT:
# USA           	 ROA mean: 0.048
# China         	 ROA mean: 0.017
# Japan         	 ROA mean: 0.028
# Germany       	 ROA mean: 0.020
# Netherlands   	 ROA mean: 0.025
# Britain       	 ROA mean: 0.033
# South Korea   	 ROA mean: 0.031
# Switzerland   	 ROA mean: 0.035
# France        	 ROA mean: 0.025
# Taiwan        	 ROA mean: 0.055
# Singapore     	 ROA mean: 0.023
# Italy         	 ROA mean: 0.004
# Russia        	 ROA mean: 0.031
# Spain         	 ROA mean: 0.035
# Brazil        	 ROA mean: 0.017
# Mexico        	 ROA mean: -0.042
# Luxembourg    	 ROA mean: 0.024
# India         	 ROA mean: 0.052
# Malaysia      	 ROA mean: 0.030
# Thailand      	 ROA mean: 0.043
# Australia     	 ROA mean: -0.010
# Belgium       	 ROA mean: 0.005
# Norway        	 ROA mean: -0.028
# Canada        	 ROA mean: 0.024
# Ireland       	 ROA mean: 0.066
# Indonesia     	 ROA mean: 0.067
# Denmark       	 ROA mean: -0.032
# Saudi Arabia  	 ROA mean: 0.056
# Sweden        	 ROA mean: 0.082
# Finland       	 ROA mean: -0.018
# Venezuela     	 ROA mean: 0.013
# Turkey        	 ROA mean: 0.046
# U.A.E         	 ROA mean: 0.010
# Israel        	 ROA mean: 0.004
# ```

# %%
f500["country"].dropna().unique()
# Out:
# array(['USA', 'China', 'Japan', 'Germany', 'Netherlands', 'Britain',
#        'South Korea', 'Switzerland', 'France', 'Taiwan', nan, 'Singapore',
#        'Italy', 'Russia', 'Spain', 'Brazil', 'Mexico', 'Luxembourg',
#        'India', 'Malaysia', 'Thailand', 'Australia', 'Belgium', 'Norway',
#        'Canada', 'Indonesia', 'Denmark', 'Saudi Arabia', 'Sweden',
#        'Ireland', 'Turkey', 'U.A.E'], dtype=object)

# %%
# Rešitev
f500["roa"] = f500["profits"] / f500["assets"]
countries = f500["country"].dropna().unique()

for country in countries:
    filter_ = f500["country"] == country
    country_data = f500[filter_]
    roa_mean = country_data["roa"].mean()
    print(f"{country:13} \t ROA mean: {roa_mean:.3f}")
# Out:
# USA           	 ROA mean: 0.048
# China         	 ROA mean: 0.015
# Japan         	 ROA mean: 0.028
# Germany       	 ROA mean: 0.024
# Netherlands   	 ROA mean: 0.028
# Britain       	 ROA mean: 0.036
# South Korea   	 ROA mean: 0.033
# Switzerland   	 ROA mean: 0.036
# France        	 ROA mean: 0.025
# Taiwan        	 ROA mean: 0.055
# Singapore     	 ROA mean: 0.023
# Italy         	 ROA mean: 0.004
# Russia        	 ROA mean: 0.031
# Spain         	 ROA mean: 0.035
# Brazil        	 ROA mean: 0.017
# Mexico        	 ROA mean: -0.042
# Luxembourg    	 ROA mean: 0.024
# India         	 ROA mean: 0.052
# Malaysia      	 ROA mean: 0.030
# Thailand      	 ROA mean: 0.043
# Australia     	 ROA mean: -0.010
# Belgium       	 ROA mean: 0.005
# Norway        	 ROA mean: -0.028
# Canada        	 ROA mean: 0.025
# Indonesia     	 ROA mean: 0.067
# Denmark       	 ROA mean: -0.032
# Saudi Arabia  	 ROA mean: 0.056
# Sweden        	 ROA mean: 0.082
# Ireland       	 ROA mean: 0.120
# Turkey        	 ROA mean: 0.046
# U.A.E         	 ROA mean: 0.010
