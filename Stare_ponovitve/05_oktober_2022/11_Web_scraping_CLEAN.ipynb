# %% [markdown]
# # Web scraping

# %% [markdown]
# ## Vprašanje

# %%
import pandas as pd

# %%
pd.date_range("00:00:00", periods=60, freq="s").to_frame().to_csv("test.csv", index=False)

# %% [markdown]
# ## What Is Web Scraping?

# %%
import pandas as pd

# %% [markdown]
# <img class="progressiveMedia-image js-progressiveMedia-image" data-src="https://cdn-images-1.medium.com/max/1600/1*GOyqaID2x1N5lD_rhTDKVQ.png" src="https://cdn-images-1.medium.com/max/1600/1*GOyqaID2x1N5lD_rhTDKVQ.png">

# %% [markdown]
# ### Why Web Scraping for Data Science?

# %% [markdown]
# ## Network complexity

# %% [markdown]
# ## HTTP

# %% [markdown]
# ## HTTP in Python: The Requests Library

# %% [markdown]
# [Requests: HTTP for Humans](https://2.python-requests.org/en/master/)

# %%
import requests

# %%
url = 'http://example.com/'

r = requests.get(url)

# %%
type(r)
# Out:
# requests.models.Response

# %%
r.status_code
# Out:
# 200

# %% [markdown]
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Status

# %%
if r:
    print("ok")
else:
    print("error")
# Out:
# ok

# %%
r.reason
# Out:
# 'OK'

# %%
r.headers
# Out:
# {'Content-Encoding': 'gzip', 'Accept-Ranges': 'bytes', 'Age': '284515', 'Cache-Control': 'max-age=604800', 'Content-Type': 'text/html; charset=UTF-8', 'Date': 'Mon, 19 Dec 2022 15:35:27 GMT', 'Etag': '"3147526947"', 'Expires': 'Mon, 26 Dec 2022 15:35:27 GMT', 'Last-Modified': 'Thu, 17 Oct 2019 07:18:26 GMT', 'Server': 'ECS (dcb/7F18)', 'Vary': 'Accept-Encoding', 'X-Cache': 'HIT', 'Content-Length': '648'}

# %%
r.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
r.content
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %% [markdown]
#     <title>Example Domain</title>

# %% [markdown]
#     <a href="https://www.iana.org/domains/example">More information...</a>

# %% [markdown]
# ### Primer

# %% [markdown]
# https://www.bsp-southpool.com/rezultati-trgovanja-slovenija.html

# %% [markdown]
#     <a href="files/documents/trading/MarketResultsAuction.xlsx">Rezultati trgovanja za dan vnaprej- Slovenija - 2022</a>
#     <a href="files/documents/trading/MarketResultsAuction_2021.xlsx">Rezultati trgovanja za dan vnaprej- Slovenija - 2021</a>
#     <a href="files/documents/trading/MarketResultsAuction_2020.xlsx">Rezultati trgovanja za dan vnaprej- Slovenija - 2020</a>

# %%
url = "https://www.bsp-southpool.com/files/documents/trading/MarketResultsAuction.xlsx"
data = pd.read_excel(url)

# %%
data.head()
# Out:
#             Unnamed: 0 Market: Slovenia Auction Trading Prices  (EUR/MWh)  \
# 0        Delivery Date                                               Base
# 1  2022-01-01 00:00:00                                              84.08
# 2  2022-01-02 00:00:00                                              55.83
# 3  2022-01-03 00:00:00                                             164.63
# 4  2022-01-04 00:00:00                                             154.56
#
#   Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0  Euro-Peak    00 - 01    01 - 02    02 - 03    03 - 04    04 - 05
# 1     102.79   61.83783   51.44327   55.91396   46.94279    37.6721
# 2       68.7   57.07848   52.58649   48.97417   34.94069   29.55949
# 3     236.48   20.89311    9.70069    9.70069    7.07342    8.98849
# 4        182  110.14028  110.21123  106.86024  104.14071  103.40589
#
#   Unnamed: 8 Unnamed: 9  ... Unnamed: 17 Unnamed: 18 Unnamed: 19 Unnamed: 20  \
# 0    05 - 06    06 - 07  ...     14 - 15     15 - 16     16 - 17     17 - 18
# 1       39.7   40.58627  ...       97.17         101   126.60311    149.9731
# 2   33.96974   34.51649  ...    65.19346    60.07324    88.45866    95.40073
# 3   15.33601  162.86028  ...      207.16         265         270   292.36127
# 4  114.50388     156.91  ...         179   180.93289     166.994      189.88
#
#   Unnamed: 21 Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26
# 0     18 - 19     19 - 20     20 - 21     21 - 22     22 - 23     23 - 24
# 1   146.33463   140.28218   121.88389   102.60927    97.46378    85.15867
# 2    86.70908       71.72    56.72824    46.16462    46.28878    32.93397
# 3   265.43399       240.1      221.16      199.08      159.56    96.93058
# 4   184.93974   178.98561   156.11893   143.13857      137.92    99.47078
#
# [5 rows x 27 columns]

# %%
import requests
from datetime import datetime

# %%
url = "https://www.bsp-southpool.com/files/documents/trading/MarketResultsAuction.xlsx"
resp = requests.get(url)

if resp:
    with open(f"MarketResultsAuction_{datetime.now().date()}.xlsx", "wb") as output:
        output.write(resp.content)

# %% [markdown]
# ## HTML and CSS

# %% [markdown]
# ### Hypertext Markup Language: HTML

# %% [markdown]
# Link strani: https://en.wikipedia.org/w/index.php?title=List_of_Game_of_Thrones_episodes

# %%
import requests

url_got = 'https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes'
r = requests.get(url_got)

# %%
tables = pd.read_html("https://en.wikipedia.org/wiki/List_of_Game_of_Thrones_episodes")

# %%
type(tables)
# Out:
# list

# %%
len(tables)
# Out:
# 18

# %%
episodes = pd.concat(tables[1:9])
episodes.columns = ["no_overall", "no_in_season", "title", "directed_by", "written_by", "original_air_date", "us_viewers"]
episodes["us_viewers"] = episodes["us_viewers"].str.replace(r"\[.+\]", "", regex=True).astype("float")
episodes.head()
# Out:
#    no_overall  no_in_season                                    title  \
# 0           1             1                       "Winter Is Coming"
# 1           2             2                          "The Kingsroad"
# 2           3             3                              "Lord Snow"
# 3           4             4  "Cripples, Bastards, and Broken Things"
# 4           5             5                  "The Wolf and the Lion"
#
#       directed_by                   written_by original_air_date  us_viewers
# 0  Tim Van Patten  David Benioff & D. B. Weiss    April 17, 2011        2.22
# 1  Tim Van Patten  David Benioff & D. B. Weiss    April 24, 2011        2.20
# 2      Brian Kirk  David Benioff & D. B. Weiss       May 1, 2011        2.44
# 3      Brian Kirk                 Bryan Cogman       May 8, 2011        2.45
# 4      Brian Kirk  David Benioff & D. B. Weiss      May 15, 2011        2.58

# %%
import matplotlib.pyplot as plt
episodes.plot(x="no_overall", y="us_viewers")
plt.show()

# %% [markdown]
# - `<p>...</p>` to enclose a paragraph;
# - `<br>` to set a line break;
# - `<table>...</table>` to start a table block, inside; `<tr>...<tr/>` is used for the rows; and `<td>...</td>` cells;
# - `<img>` for images;
# - `<h1>...</h1> to <h6>...</h6>` for headers;
# - `<div>...</div>` to indicate a “division” in an HTML document, basically used to group a set of elements;
# - `<a>...</a>` for hyperlinks;
# - `<ul>...</ul>, <ol>...</ol>` for unordered and ordered lists respectively; inside of these, `<li>...</li>` is used for each list item.

# %% [markdown]
# ## Using Your Browser as a Development Tool

# %% [markdown]
# ## The Beautiful Soup Library

# %% [markdown]
# https://pypi.org/project/beautifulsoup4/

# %%
from bs4 import BeautifulSoup

# %%
url = "https://developer.mozilla.org/en-US/docs/Web/HTTP/Status"
r = requests.get(url)
html_soup = BeautifulSoup(r.text, "lxml")

# %%
type(html_soup)
# Out:
# bs4.BeautifulSoup

# %%
sections = html_soup.find_all("section")
sections = sections[2:7]

my_status_codes = []

for section in sections:
    elements = section.find("dl")
    dts = elements.find_all("dt")
    dds = elements.find_all("dd")
    
    for dt, dd in zip(dts, dds):
        code_metadata = {}
        code_metadata["status_code"] = dt.find("code").text.split()[0]
        code_metadata["reason"] = dt.find("code").text.split()[1]
        code_metadata["description"] = dd.find("p").text.strip()
        my_status_codes.append(code_metadata)

# %%
status_codes_df = pd.DataFrame(my_status_codes)

# %%
status_codes_df.head()
# Out:
#   status_code      reason                                        description
# 0         100    Continue  This interim response indicates that the clien...
# 1         101   Switching  This code is sent in response to an Upgrade re...
# 2         102  Processing  This code indicates that the server has receiv...
# 3         103       Early  This status code is primarily intended to be u...
# 4         200          OK  The request succeeded. The result meaning of "...

# %%
requests.get("https://cyber.ltfe.org/").text
# Out:
# '<!DOCTYPE html><html lang=en><head><script async src="https://www.googletagmanager.com/gtag/js?id=UA-69442206-2"></script><script>window.dataLayer = window.dataLayer || [];\n\n        function gtag() {\n            dataLayer.push(arguments);\n        }\n\n        gtag(\'js\', new Date());\n\n        gtag(\'config\', \'UA-69442206-2\');</script><meta charset=utf-8><meta http-equiv=X-UA-Compatible content="IE=edge"><meta name=viewport content="width=device-width,initial-scale=1"><link rel=apple-touch-icon sizes=180x180 href=./favicons/apple-touch-icon.png><!--[if IE]><link rel="icon" type="image/png" sizes="32x32" href="./favicons/favicon-32x32.png"><![endif]--><link rel=icon type=image/png sizes=16x16 href=./favicons/favicon-16x16.png><link rel=manifest href=./favicons/site.webmanifest><link rel=mask-icon href=./favicons/safari-pinned-tab.svg color=#5bbad5><link rel="shortcut icon" href=./favicons/favicon.ico><meta name=msapplication-TileColor content=#da532c><meta name=msapplication-config content=./favicons/browserconfig.xml><meta name=theme-color content=#ffffff><title>CyberLab</title><link href=/css/app.5f79ea36.css rel=preload as=style><link href=/css/chunk-vendors.0909966d.css rel=preload as=style><link href=/js/app.bc36ae3c.js rel=preload as=script><link href=/js/chunk-vendors.8c1b15ae.js rel=preload as=script><link href=/css/chunk-vendors.0909966d.css rel=stylesheet><link href=/css/app.5f79ea36.css rel=stylesheet><link rel=icon type=image/png sizes=32x32 href=/img/icons/favicon-32x32.png><link rel=icon type=image/png sizes=16x16 href=/img/icons/favicon-16x16.png><link rel=manifest href=/manifest.json><meta name=theme-color content=#4DBA87><meta name=apple-mobile-web-app-capable content=no><meta name=apple-mobile-web-app-status-bar-style content=default><meta name=apple-mobile-web-app-title content=cyberlab-web><link rel=apple-touch-icon href=/img/icons/apple-touch-icon-152x152.png><link rel=mask-icon href=/img/icons/safari-pinned-tab.svg color=#4DBA87><meta name=msapplication-TileImage content=/img/icons/msapplication-icon-144x144.png><meta name=msapplication-TileColor content=#000000></head><body><noscript><strong>We\'re sorry but Webpack App doesn\'t work properly without JavaScript enabled. Please enable it to continue.</strong></noscript><div id=app></div><script src=/js/chunk-vendors.8c1b15ae.js></script><script src=/js/app.bc36ae3c.js></script></body></html>'

# %% [markdown]
# https://www.selenium.dev/

# %% [markdown]
# ## Web APIs

# %%
from typing import Dict
from datetime import datetime
import os
import time

bicikelj_url = "https://opendata.si/promet/bicikelj/list/"


def get_data(url: str) -> Dict:
    bicikelj_data = requests.get(url)
    if bicikelj_data.status_code == 200:
        print(f"Getting data from {url} ...")
        return bicikelj_data.json()
    else:
        return {}
    
def extract_timestamp_from_data(data: Dict) -> datetime:
    updated = data["updated"]
    updated = datetime.fromtimestamp(updated)
    return updated
    
def extract_station_data(data: Dict) -> Dict:
    all_data = {}
    for _, station_data in data["markers"].items():
        station_name = station_data["name"].lower().replace(" ", "_").replace("-", "_").replace(".", "")
        available_procentage = round(int(station_data["station"]["available"]) / int(station_data["station"]["total"]),2) * 100       
        all_data[station_name] = available_procentage
    return all_data
    

for _ in range(10):
    data = get_data(bicikelj_url)
    last_updated_timestamp = extract_timestamp_from_data(data)
    print(f"Data for {last_updated_timestamp}.")
    parsed_data = extract_station_data(data)
    parsed_data = pd.DataFrame(parsed_data, index=[last_updated_timestamp])
    parsed_data.to_csv("data/bicikelj.csv", mode="a", header=not os.path.exists("data/bicikelj.csv"))
    time.sleep(10)
# Out:
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.
# Getting data from https://opendata.si/promet/bicikelj/list/ ...
# Data for 2022-12-19 16:57:27.

# %%
# url = "https://api.jcdecaux.com/vls/v3/stations?apiKey=frifk0jbxfefqqniqez09tw4jvk37wyf823b5j1i&contract=ljubljana"

# requests.get(url).json()
# Out:
# [{'number': 59,
#   'contractName': 'ljubljana',
#   'name': 'LIDL BEŽIGRAD',
#   'address': 'Bežigrad 11',
#   'position': {'latitude': 46.063797, 'longitude': 14.506854},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:16Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 54,
#   'contractName': 'ljubljana',
#   'name': 'ŠMARTINSKI PARK',
#   'address': 'Smartinska cesta 58',
#   'position': {'latitude': 46.065206, 'longitude': 14.529911},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:49Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 45,
#   'contractName': 'ljubljana',
#   'name': 'SAVSKO NASELJE 1-ŠMARTINSKA CESTA',
#   'address': 'Savska cesta 1',
#   'position': {'latitude': 46.062475, 'longitude': 14.524321},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:02Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 68,
#   'contractName': 'ljubljana',
#   'name': 'ČRNUČE',
#   'address': 'Dunajska cesta',
#   'position': {'latitude': 46.102446, 'longitude': 14.530213},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:52Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 11,
#   'contractName': 'ljubljana',
#   'name': 'VILHARJEVA CESTA',
#   'address': 'Vilharjeva cesta 23',
#   'position': {'latitude': 46.06005, 'longitude': 14.51302},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:43Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 16,
#     'stands': 4,
#     'mechanicalBikes': 16,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 16,
#     'stands': 4,
#     'mechanicalBikes': 16,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 10,
#   'contractName': 'ljubljana',
#   'name': 'MASARYKOVA DDC',
#   'address': 'Masarykova cesta 14',
#   'position': {'latitude': 46.05763, 'longitude': 14.514264},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:49Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 4,
#     'stands': 14,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 4,
#     'stands': 14,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 2,
#   'contractName': 'ljubljana',
#   'name': 'POGAČARJEV TRG-TRŽNICA',
#   'address': 'Pogačarjev trg 3',
#   'position': {'latitude': 46.051093, 'longitude': 14.507186},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:46Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 15,
#     'stands': 3,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 15,
#     'stands': 3,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 4,
#   'contractName': 'ljubljana',
#   'name': 'CANKARJEVA UL.-NAMA',
#   'address': 'Cankarjeva cesta 1',
#   'position': {'latitude': 46.052431, 'longitude': 14.503257},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:28Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 15,
#     'stands': 11,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'mainStands': {'availabilities': {'bikes': 15,
#     'stands': 11,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'overflowStands': None},
#  {'number': 41,
#   'contractName': 'ljubljana',
#   'name': 'ANTONOV TRG',
#   'address': 'Tržaška 91',
#   'position': {'latitude': 46.041753, 'longitude': 14.477016},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:56Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 73,
#   'contractName': 'ljubljana',
#   'name': 'PRUŠNIKOVA',
#   'address': 'Prušnikova ulica',
#   'position': {'latitude': 46.090608, 'longitude': 14.471637},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:16Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 76,
#   'contractName': 'ljubljana',
#   'name': 'TEHNOLOŠKI PARK',
#   'address': 'Tehnološki park',
#   'position': {'latitude': 46.04843, 'longitude': 14.461086},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:23Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 66,
#   'contractName': 'ljubljana',
#   'name': 'KOSEŠKI BAJER',
#   'address': 'Koseška cesta',
#   'position': {'latitude': 46.068443, 'longitude': 14.470913},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:56:51Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 10,
#     'stands': 10,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 10,
#     'stands': 10,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 19,
#   'contractName': 'ljubljana',
#   'name': 'TIVOLI',
#   'address': 'Celovška cesta 26',
#   'position': {'latitude': 46.05952, 'longitude': 14.4982},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:26Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 20,
#     'stands': 0,
#     'mechanicalBikes': 20,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 20,
#     'stands': 0,
#     'mechanicalBikes': 20,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 25,
#   'contractName': 'ljubljana',
#   'name': 'TRŽNICA MOSTE',
#   'address': 'Zaloška cesta 54',
#   'position': {'latitude': 46.055801, 'longitude': 14.534156},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:43Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 12,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 21},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 12,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 21},
#   'overflowStands': None},
#  {'number': 6,
#   'contractName': 'ljubljana',
#   'name': 'GRUDNOVO NABREŽJE-KARLOVŠKA C.',
#   'address': 'Grudnovo nabrežje 3',
#   'position': {'latitude': 46.045748, 'longitude': 14.506196},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:57Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 3,
#     'stands': 15,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 3,
#     'stands': 15,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 51,
#   'contractName': 'ljubljana',
#   'name': 'LIDL-LITIJSKA CESTA',
#   'address': 'Litijska cesta 53',
#   'position': {'latitude': 46.047689, 'longitude': 14.547416},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:30Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 4,
#     'stands': 16,
#     'mechanicalBikes': 4,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 31,
#   'contractName': 'ljubljana',
#   'name': 'ŠPORTNI CENTER STOŽICE',
#   'address': 'Vojkova cesta 91',
#   'position': {'latitude': 46.08259, 'longitude': 14.52016},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T11:56:56Z',
#   'connected': False,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 16,
#     'stands': 10,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'mainStands': {'availabilities': {'bikes': 16,
#     'stands': 10,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'overflowStands': None},
#  {'number': 22,
#   'contractName': 'ljubljana',
#   'name': 'ŠPICA',
#   'address': 'Prule 8',
#   'position': {'latitude': 46.040213, 'longitude': 14.512044},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:56Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 11,
#     'stands': 7,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 11,
#     'stands': 7,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 80,
#   'contractName': 'ljubljana',
#   'name': 'ROŠKA - STRELIŠKA',
#   'address': 'Roška cesta',
#   'position': {'latitude': 46.045, 'longitude': 14.51846},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:06Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 8,
#   'contractName': 'ljubljana',
#   'name': 'BAVARSKI DVOR',
#   'address': 'Slovenska cesta 55c',
#   'position': {'latitude': 46.05682, 'longitude': 14.50551},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:55Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 14,
#     'stands': 5,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 14,
#     'stands': 5,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 20,
#   'contractName': 'ljubljana',
#   'name': 'STARA CERKEV',
#   'address': 'Celovška cesta 69',
#   'position': {'latitude': 46.06342, 'longitude': 14.494588},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:44Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 7,
#     'stands': 7,
#     'mechanicalBikes': 7,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 14},
#   'mainStands': {'availabilities': {'bikes': 7,
#     'stands': 7,
#     'mechanicalBikes': 7,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 14},
#   'overflowStands': None},
#  {'number': 46,
#   'contractName': 'ljubljana',
#   'name': 'SITULA',
#   'address': 'Vilharjeva cesta 44',
#   'position': {'latitude': 46.059433, 'longitude': 14.52051},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:31Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 0,
#     'stands': 19,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 0,
#     'stands': 19,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 17,
#   'contractName': 'ljubljana',
#   'name': 'ILIRSKA ULICA',
#   'address': 'Ilirska ulica 1',
#   'position': {'latitude': 46.053144, 'longitude': 14.513479},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:34Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 13,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 13,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 72,
#   'contractName': 'ljubljana',
#   'name': 'LIDL - RUDNIK',
#   'address': 'Betettova cesta',
#   'position': {'latitude': 46.020012, 'longitude': 14.532479},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:56:39Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 7,
#     'stands': 13,
#     'mechanicalBikes': 7,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 7,
#     'stands': 13,
#     'mechanicalBikes': 7,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 64,
#   'contractName': 'ljubljana',
#   'name': 'KOPALIŠČE KOLEZIJA',
#   'address': 'Gunduličeva ulica',
#   'position': {'latitude': 46.042867, 'longitude': 14.495239},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:19Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 0,
#     'stands': 20,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 0,
#     'stands': 20,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 74,
#   'contractName': 'ljubljana',
#   'name': 'POVŠETOVA - KAJUHOVA',
#   'address': 'Povšetova - Kajuhova',
#   'position': {'latitude': 46.051512, 'longitude': 14.539272},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:56:47Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 29,
#   'contractName': 'ljubljana',
#   'name': 'DUNAJSKA C.-PS MERCATOR',
#   'address': 'Dunajska cesta 105',
#   'position': {'latitude': 46.074193, 'longitude': 14.511134},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:33Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 1,
#     'stands': 17,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 1,
#     'stands': 17,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 34,
#   'contractName': 'ljubljana',
#   'name': 'CITYPARK',
#   'address': 'Citypark - Šmartinska 152 g',
#   'position': {'latitude': 46.068805, 'longitude': 14.546257},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:19Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 32,
#   'contractName': 'ljubljana',
#   'name': 'KOPRSKA ULICA',
#   'address': 'Koprska ulica 98',
#   'position': {'latitude': 46.033408, 'longitude': 14.482468},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:22Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 6,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 8},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 6,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 8},
#   'overflowStands': None},
#  {'number': 30,
#   'contractName': 'ljubljana',
#   'name': 'LIDL - VOJKOVA CESTA',
#   'address': '',
#   'position': {'latitude': 46.07589, 'longitude': 14.52011},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:01Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 55,
#   'contractName': 'ljubljana',
#   'name': 'POLJANSKA-POTOČNIKOVA',
#   'address': 'Poljanska cesta 50',
#   'position': {'latitude': 46.048982, 'longitude': 14.522709},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:18Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 57,
#   'contractName': 'ljubljana',
#   'name': 'POVŠETOVA-GRABLOVIČEVA',
#   'address': 'Grabloviceva ulica 60',
#   'position': {'latitude': 46.051863, 'longitude': 14.530349},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:16Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 3,
#     'stands': 16,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 19},
#   'mainStands': {'availabilities': {'bikes': 3,
#     'stands': 16,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 19},
#   'overflowStands': None},
#  {'number': 12,
#   'contractName': 'ljubljana',
#   'name': 'PARK NAVJE-ŽELEZNA CESTA',
#   'address': 'Železna cesta 18',
#   'position': {'latitude': 46.06361, 'longitude': 14.51315},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:20Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 71,
#   'contractName': 'ljubljana',
#   'name': 'ZALOG',
#   'address': 'Zaloška cesta',
#   'position': {'latitude': 46.06043, 'longitude': 14.613797},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:36Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 53,
#   'contractName': 'ljubljana',
#   'name': 'CESTA NA ROŽNIK',
#   'address': 'Cesta na Rožnik 1',
#   'position': {'latitude': 46.053241, 'longitude': 14.486206},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:14Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 48,
#   'contractName': 'ljubljana',
#   'name': 'HOFER-KAJUHOVA',
#   'address': 'Kajuhova ulica 42',
#   'position': {'latitude': 46.056405, 'longitude': 14.540901},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:45Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 27,
#   'contractName': 'ljubljana',
#   'name': 'DUNAJSKA C.-PS PETROL',
#   'address': 'Dunajska cesta 50',
#   'position': {'latitude': 46.065136, 'longitude': 14.509112},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:45Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 69,
#   'contractName': 'ljubljana',
#   'name': 'STUDENEC',
#   'address': 'Zaloška cesta',
#   'position': {'latitude': 46.054615, 'longitude': 14.576031},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:55Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 3,
#     'stands': 17,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 3,
#     'stands': 17,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 14,
#   'contractName': 'ljubljana',
#   'name': 'PARKIRIŠČE NUK 2-FF',
#   'address': 'Zoisova cesta 2',
#   'position': {'latitude': 46.046377, 'longitude': 14.501256},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:03Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 14,
#     'stands': 6,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 14,
#     'stands': 6,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 42,
#   'contractName': 'ljubljana',
#   'name': 'BRATOVŠEVA PLOŠČAD',
#   'address': 'Dunajska 211',
#   'position': {'latitude': 46.08929, 'longitude': 14.513751},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:11Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 3,
#   'contractName': 'ljubljana',
#   'name': 'KONGRESNI TRG-ŠUBIČEVA ULICA',
#   'address': 'Kongresni trg 3',
#   'position': {'latitude': 46.050388, 'longitude': 14.504623},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:42Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 43,
#   'contractName': 'ljubljana',
#   'name': 'BS4-STOŽICE',
#   'address': 'Dunajska 186',
#   'position': {'latitude': 46.086761, 'longitude': 14.514151},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:32Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 13,
#     'stands': 7,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 13,
#     'stands': 7,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 78,
#   'contractName': 'ljubljana',
#   'name': 'GERBIČEVA - ŠPORTNI PARK SVOBODA',
#   'address': 'Gerbičeva ulica 61',
#   'position': {'latitude': 46.039384, 'longitude': 14.485458},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:41Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 13,
#     'stands': 7,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 13,
#     'stands': 7,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 52,
#   'contractName': 'ljubljana',
#   'name': 'ŽIVALSKI VRT',
#   'address': 'Večna pot 70',
#   'position': {'latitude': 46.052454, 'longitude': 14.472149},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:33Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 10,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 10,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 82,
#   'contractName': 'ljubljana',
#   'name': 'VOKA - SLOVENČEVA',
#   'address': 'Vodovodna cesta 90',
#   'position': {'latitude': 46.075207, 'longitude': 14.504734},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:25Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 35,
#   'contractName': 'ljubljana',
#   'name': 'BTC CITY/DVORANA A',
#   'address': 'BTC City/Dvorana A',
#   'position': {'latitude': 46.065297, 'longitude': 14.543996},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:36Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 11,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 11,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 37,
#   'contractName': 'ljubljana',
#   'name': 'TRNOVO',
#   'address': 'TRNOVO',
#   'position': {'latitude': 46.03784, 'longitude': 14.50001},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:49Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 38,
#   'contractName': 'ljubljana',
#   'name': 'P+R BARJE',
#   'address': 'P+R BARJE',
#   'position': {'latitude': 46.02749, 'longitude': 14.49958},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:41Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 26,
#   'contractName': 'ljubljana',
#   'name': 'ROŽNA DOLINA-ŠKRABČEVA UL.',
#   'address': 'Škrabčeva ulica 2',
#   'position': {'latitude': 46.051439, 'longitude': 14.49273},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:29Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 8,
#     'stands': 10,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 8,
#     'stands': 10,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 21,
#   'contractName': 'ljubljana',
#   'name': 'KINO ŠIŠKA',
#   'address': 'Celovška cesta 111c',
#   'position': {'latitude': 46.06928, 'longitude': 14.48971},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:43Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 14,
#     'stands': 12,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'mainStands': {'availabilities': {'bikes': 14,
#     'stands': 12,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'overflowStands': None},
#  {'number': 24,
#   'contractName': 'ljubljana',
#   'name': 'ZALOŠKA C.-GRABLOVIČEVA C.',
#   'address': 'Zaloška cesta 16',
#   'position': {'latitude': 46.05441, 'longitude': 14.52978},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:47Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 1,
#     'stands': 15,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 16},
#   'mainStands': {'availabilities': {'bikes': 1,
#     'stands': 15,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 16},
#   'overflowStands': None},
#  {'number': 49,
#   'contractName': 'ljubljana',
#   'name': 'BRODARJEV TRG',
#   'address': 'Nove Fuzine 8',
#   'position': {'latitude': 46.054398, 'longitude': 14.553319},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:43Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 79,
#   'contractName': 'ljubljana',
#   'name': 'DOLENJSKA C. - STRELIŠČE',
#   'address': 'Dolenjska c. 11',
#   'position': {'latitude': 46.038866, 'longitude': 14.517605},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:00:58Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 3,
#     'stands': 17,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 3,
#     'stands': 17,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 47,
#   'contractName': 'ljubljana',
#   'name': 'ŠTEPANJSKO NASELJE 1-JAKČEVA ULICA',
#   'address': 'Jakčeva ulica 37',
#   'position': {'latitude': 46.053047, 'longitude': 14.545125},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:08Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 6,
#     'stands': 13,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 19},
#   'mainStands': {'availabilities': {'bikes': 6,
#     'stands': 13,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 19},
#   'overflowStands': None},
#  {'number': 75,
#   'contractName': 'ljubljana',
#   'name': 'SOSESKA NOVO BRDO',
#   'address': 'Pot rdečega križa',
#   'position': {'latitude': 46.045617, 'longitude': 14.462281},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:42Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 17,
#     'stands': 3,
#     'mechanicalBikes': 17,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 17,
#     'stands': 3,
#     'mechanicalBikes': 17,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 58,
#   'contractName': 'ljubljana',
#   'name': 'TRŽNICA KOSEZE',
#   'address': 'Vodnikova cesta 187',
#   'position': {'latitude': 46.074315, 'longitude': 14.475483},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:01:47Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 13,
#     'stands': 5,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 13,
#     'stands': 5,
#     'mechanicalBikes': 13,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 62,
#   'contractName': 'ljubljana',
#   'name': 'ALEJA - CELOVŠKA CESTA',
#   'address': 'Aleja - Celovška Cesta',
#   'position': {'latitude': 46.077302, 'longitude': 14.482581},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:37Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 33,
#   'contractName': 'ljubljana',
#   'name': 'MERCATOR CENTER ŠIŠKA',
#   'address': 'Cesta Ljubljanske brigade 33',
#   'position': {'latitude': 46.087079, 'longitude': 14.475439},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:56:09Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 0,
#     'stands': 22,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 22},
#   'mainStands': {'availabilities': {'bikes': 0,
#     'stands': 22,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 22},
#   'overflowStands': None},
#  {'number': 16,
#   'contractName': 'ljubljana',
#   'name': 'GH ŠENTPETER-NJEGOŠEVA C.',
#   'address': 'Zaloška cesta 1',
#   'position': {'latitude': 46.05257, 'longitude': 14.51928},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:29Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 10,
#     'stands': 14,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 24},
#   'mainStands': {'availabilities': {'bikes': 10,
#     'stands': 14,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 24},
#   'overflowStands': None},
#  {'number': 84,
#   'contractName': 'ljubljana',
#   'name': 'HOFER - POLJE',
#   'address': 'Polje 51',
#   'position': {'latitude': 46.053718, 'longitude': 14.589284},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:32Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 9,
#     'stands': 11,
#     'mechanicalBikes': 9,
# ...
#   'address': 'Zadobrovška cesta',
#   'position': {'latitude': 46.05722, 'longitude': 14.583537},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:36Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 83,
#   'contractName': 'ljubljana',
#   'name': 'SUPERNOVA LJUBLJANA - RUDNIK',
#   'address': 'Jurčkova 223',
#   'position': {'latitude': 46.021586, 'longitude': 14.536745},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:15Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 12,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 12,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 56,
#   'contractName': 'ljubljana',
#   'name': 'SREDNJA FRIZERSKA ŠOLA',
#   'address': 'Litostrojska cesta 53',
#   'position': {'latitude': 46.080522, 'longitude': 14.491439},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:53:57Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 8,
#     'stands': 12,
#     'mechanicalBikes': 8,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 9,
#   'contractName': 'ljubljana',
#   'name': 'TRG OF-KOLODVORSKA UL.',
#   'address': 'Trg OF 12',
#   'position': {'latitude': 46.057421, 'longitude': 14.510265},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:48Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 10,
#     'stands': 16,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'mainStands': {'availabilities': {'bikes': 10,
#     'stands': 16,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 26},
#   'overflowStands': None},
#  {'number': 13,
#   'contractName': 'ljubljana',
#   'name': 'TRG MDB',
#   'address': 'Trg MDB 9',
#   'position': {'latitude': 46.047565, 'longitude': 14.495687},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:50Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 10,
#     'stands': 10,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 10,
#     'stands': 10,
#     'mechanicalBikes': 10,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 18,
#   'contractName': 'ljubljana',
#   'name': 'TRŽAŠKA C.-ILIRIJA',
#   'address': 'Tržaška cesta 37',
#   'position': {'latitude': 46.044629, 'longitude': 14.486699},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:00Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 17,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 17,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 1,
#   'contractName': 'ljubljana',
#   'name': 'PREŠERNOV TRG-PETKOVŠKOVO NABREŽJE',
#   'address': 'Prešernov trg 6',
#   'position': {'latitude': 46.051367, 'longitude': 14.506542},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:22Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 1,
#     'stands': 19,
#     'mechanicalBikes': 1,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 60,
#   'contractName': 'ljubljana',
#   'name': 'MERCATOR MARKET - CELOVŠKA C. 163',
#   'address': 'Celovška 163',
#   'position': {'latitude': 46.073264, 'longitude': 14.485942},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:53Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 6,
#     'stands': 14,
#     'mechanicalBikes': 6,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 44,
#   'contractName': 'ljubljana',
#   'name': 'SAVSKO NASELJE 2-LINHARTOVA CESTA',
#   'address': 'Topniška 54',
#   'position': {'latitude': 46.064546, 'longitude': 14.518013},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:38Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 14,
#     'stands': 6,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 14,
#     'stands': 6,
#     'mechanicalBikes': 14,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 5,
#   'contractName': 'ljubljana',
#   'name': 'BREG',
#   'address': 'Breg 20',
#   'position': {'latitude': 46.046498, 'longitude': 14.505148},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:00Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 16,
#     'stands': 4,
#     'mechanicalBikes': 16,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 16,
#     'stands': 4,
#     'mechanicalBikes': 16,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 36,
#   'contractName': 'ljubljana',
#   'name': 'BTC CITY ATLANTIS',
#   'address': 'BTC City Atlantis',
#   'position': {'latitude': 46.063081, 'longitude': 14.547851},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:54Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 15,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 63,
#   'contractName': 'ljubljana',
#   'name': 'IKEA',
#   'address': 'Švedska ulica 6',
#   'position': {'latitude': 46.065175, 'longitude': 14.539537},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:02:45Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 7,
#   'contractName': 'ljubljana',
#   'name': 'MIKLOŠIČEV PARK',
#   'address': 'Miklošičeva cesta 20',
#   'position': {'latitude': 46.054168, 'longitude': 14.50706},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:53Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 0,
#     'stands': 18,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 0,
#     'stands': 18,
#     'mechanicalBikes': 0,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 23,
#   'contractName': 'ljubljana',
#   'name': 'BARJANSKA C.-CENTER STAREJŠIH TRNOVO',
#   'address': 'Devinska ulica 1a',
#   'position': {'latitude': 46.04081, 'longitude': 14.49951},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:43Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 11,
#     'stands': 9,
#     'mechanicalBikes': 11,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 81,
#   'contractName': 'ljubljana',
#   'name': 'LEK - VEROVŠKOVA',
#   'address': 'Verovškova 57',
#   'position': {'latitude': 46.076856, 'longitude': 14.500222},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:58:47Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 15,
#   'contractName': 'ljubljana',
#   'name': 'AMBROŽEV TRG',
#   'address': 'Poljanska cesta 20c',
#   'position': {'latitude': 46.049877, 'longitude': 14.516308},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T18:03:00Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 5,
#     'stands': 13,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 5,
#     'stands': 13,
#     'mechanicalBikes': 5,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None},
#  {'number': 77,
#   'contractName': 'ljubljana',
#   'name': 'VOJKOVA - GASILSKA BRIGADA',
#   'address': 'Vojkova cesta',
#   'position': {'latitude': 46.068727, 'longitude': 14.516858},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:57:13Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 2,
#     'stands': 18,
#     'mechanicalBikes': 2,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 61,
#   'contractName': 'ljubljana',
#   'name': 'RAKOVNIK',
#   'address': 'Rakovnik',
#   'position': {'latitude': 46.036284, 'longitude': 14.522948},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:55:20Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 12,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 12,
#     'stands': 8,
#     'mechanicalBikes': 12,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 50,
#   'contractName': 'ljubljana',
#   'name': 'PREGLOV TRG',
#   'address': 'Nove Fuzine 33',
#   'position': {'latitude': 46.054554, 'longitude': 14.55908},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:54:27Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 15,
#     'stands': 5,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'mainStands': {'availabilities': {'bikes': 15,
#     'stands': 5,
#     'mechanicalBikes': 15,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 20},
#   'overflowStands': None},
#  {'number': 28,
#   'contractName': 'ljubljana',
#   'name': 'PLEČNIKOV STADION',
#   'address': 'Dunajska cesta 70',
#   'position': {'latitude': 46.06942, 'longitude': 14.51052},
#   'banking': False,
#   'bonus': False,
#   'status': 'OPEN',
#   'lastUpdate': '2022-12-19T17:59:10Z',
#   'connected': True,
#   'overflow': False,
#   'shape': None,
#   'totalStands': {'availabilities': {'bikes': 3,
#     'stands': 15,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'mainStands': {'availabilities': {'bikes': 3,
#     'stands': 15,
#     'mechanicalBikes': 3,
#     'electricalBikes': 0,
#     'electricalInternalBatteryBikes': 0,
#     'electricalRemovableBatteryBikes': 0},
#    'capacity': 18},
#   'overflowStands': None}]

# %% [markdown]
# ### Primer uporabe APIja

# %%
import requests

# %%
articles = []

# %%
url = 'https://hacker-news.firebaseio.com/v0'
top_stories = requests.get(url + '/topstories.json?print=pretty')

# %%
#top_stories.text

# %%
top_stories = top_stories.json()

# %% [markdown]
# ## Import data from web - pandas

# %% [markdown]
# ##### [Odprti podatki Slovenije](https://podatki.gov.si/)
#
#
# Na portalu OPSI boste našli vse od podatkov, orodij, do koristnih virov, s katerimi boste lahko razvijali spletne in mobilne aplikacije, oblikovali lastne infografike in drugo

# %%
data = pd.read_csv('https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv')

# %% [markdown]
# ## Web Scraping using pandas

# %% [markdown]
# > Spletna stran: https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/

# %%
tables = pd.read_html('https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list/')

# %% [markdown]
# ## Primeri

# %% [markdown]
# ### Scraping and Visualizing IMDB Ratings

# %%
import requests
from bs4 import BeautifulSoup
url = 'http://www.imdb.com/title/tt0944947/episodes'

# %%
episodes = []
ratings = []
