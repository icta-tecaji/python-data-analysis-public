# %% [markdown]
# # Priprava in čiščenje podatkov

# %%
import pandas as pd
import numpy as np

# Copy-on-Write will become the default in pandas 3.0. We recommend turning it on now to benefit from all improvements.
pd.options.mode.copy_on_write = True

# %%
# !head -n 5 data/INPUT_laptops.csv
# Out:
# Manufacturer,Model Name,Category,Screen Size,Screen,CPU,RAM, Storage,GPU,Operating System,Operating System Version,Weight,Price (Euros)
# Apple,MacBook Pro,Ultrabook,"13.3""",IPS Panel Retina Display 2560x1600,Intel Core i5 2.3GHz,8GB,128GB SSD,Intel Iris Plus Graphics 640,macOS,,1.37kg,"1339,69"
# Apple,Macbook Air,Ultrabook,"13.3""",1440x900,Intel Core i5 1.8GHz,8GB,128GB Flash Storage,Intel HD Graphics 6000,macOS,,1.34kg,"898,94"
# HP,250 G6,Notebook,"15.6""",Full HD 1920x1080,Intel Core i5 7200U 2.5GHz,8GB,256GB SSD,Intel HD Graphics 620,No OS,,1.86kg,"575,00"
# Apple,MacBook Pro,Ultrabook,"15.4""",IPS Panel Retina Display 2880x1800,Intel Core i7 2.7GHz,16GB,512GB SSD,AMD Radeon Pro 455,macOS,,1.83kg,"2537,45"

# %% [markdown]
# ## Reading CSV Files with Encodings

# %%
laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
laptops.head()
# Out:
#   Manufacturer   Model Name   Category Screen Size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
# 2           HP       250 G6   Notebook       15.6"
# 3        Apple  MacBook Pro  Ultrabook       15.4"
# 4        Apple  MacBook Pro  Ultrabook       13.3"
#
#                                Screen                         CPU   RAM  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                Storage                           GPU Operating System  \
# 0            128GB SSD  Intel Iris Plus Graphics 640            macOS
# 1  128GB Flash Storage        Intel HD Graphics 6000            macOS
# 2            256GB SSD         Intel HD Graphics 620            No OS
# 3            512GB SSD            AMD Radeon Pro 455            macOS
# 4            256GB SSD  Intel Iris Plus Graphics 650            macOS
#
#   Operating System Version  Weight Price (Euros)
# 0                      NaN  1.37kg       1339,69
# 1                      NaN  1.34kg        898,94
# 2                      NaN  1.86kg        575,00
# 3                      NaN  1.83kg       2537,45
# 4                      NaN  1.37kg       1803,60

# %%
laptops.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Manufacturer              1303 non-null   object
#  1   Model Name                1303 non-null   object
#  2   Category                  1303 non-null   object
#  3   Screen Size               1303 non-null   object
#  4   Screen                    1303 non-null   object
#  5   CPU                       1303 non-null   object
#  6   RAM                       1303 non-null   object
#  7    Storage                  1303 non-null   object
#  8   GPU                       1303 non-null   object
#  9   Operating System          1303 non-null   object
#  10  Operating System Version  1133 non-null   object
#  11  Weight                    1303 non-null   object
#  12  Price (Euros)             1303 non-null   object
# dtypes: object(13)
# memory usage: 132.5+ KB

# %% [markdown]
# ## Cleaning Column Names

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

laptops.head(2)
# Out:
#   manufacturer   model_name   category screen_size  \
# 0        Apple  MacBook Pro  Ultrabook       13.3"
# 1        Apple  Macbook Air  Ultrabook       13.3"
#
#                                screen                   cpu  ram  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                            1440x900  Intel Core i5 1.8GHz  8GB
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
#
#    weight price_euros
# 0  1.37kg     1339,69
# 1  1.34kg      898,94

# %% [markdown]
# ## Converting String Columns to Numeric

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

laptops.head(2)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
#
#                                screen                   cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz       8
# 1                            1440x900  Intel Core i5 1.8GHz       8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
#
#    weight_kg  price_euros
# 0       1.37      1339.69
# 1       1.34       898.94

# %% [markdown]
# ## Extracting Values from Strings

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

# Extracting Values from Strings
laptops["gpu_manufacturer"] = laptops["gpu"].str.split().str[0]
laptops['cpu_manufacturer'] = laptops["cpu"].str.split().str[0]

laptops.head(2)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
#
#                                screen                   cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz       8
# 1                            1440x900  Intel Core i5 1.8GHz       8
#
#                storage                           gpu     os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS        NaN
#
#    weight_kg  price_euros gpu_manufacturer cpu_manufacturer
# 0       1.37      1339.69            Intel            Intel
# 1       1.34       898.94            Intel            Intel

# %% [markdown]
# ## Correcting Bad Values - map() method

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

# Extracting Values from Strings
laptops["gpu_manufacturer"] = laptops["gpu"].str.split().str[0]
laptops['cpu_manufacturer'] = laptops["cpu"].str.split().str[0]

# Correcting Bad Values - map() method - če vrednost pozabimo postane nan
mapping_os = {
    "macOS": "mac",
    "No OS": None,
    "Windows": "windows",
    "Mac OS": "mac",
    "Linux": "linux",
    "Android": "android",
    "Chrome OS": "chrome_os"
}
laptops["os"] = laptops["os"].map(mapping_os)

laptops.head(2)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
#
#                                screen                   cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz       8
# 1                            1440x900  Intel Core i5 1.8GHz       8
#
#                storage                           gpu   os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  mac        NaN
# 1  128GB Flash Storage        Intel HD Graphics 6000  mac        NaN
#
#    weight_kg  price_euros gpu_manufacturer cpu_manufacturer
# 0       1.37      1339.69            Intel            Intel
# 1       1.34       898.94            Intel            Intel

# %% [markdown]
# ## Introduction to Missing Data

# %%
laptops.isnull().sum()
# Out:
# manufacturer            0
# model_name              0
# category                0
# screen_size_inches      0
# screen                  0
# cpu                     0
# ram_gb                  0
# storage                 0
# gpu                     0
# os                     66
# os_version            170
# weight_kg               0
# price_euros             0
# gpu_manufacturer        0
# cpu_manufacturer        0
# dtype: int64

# %%
laptops["os_version"].value_counts(dropna=False)
# Out:
# os_version
# 10      1072
# NaN      170
# 7         45
# X          8
# 10 S       8
# Name: count, dtype: int64

# %%
laptops.loc[laptops["os_version"].isnull(), "os"].value_counts()
# Out:
# os
# linux        62
# chrome_os    27
# mac          13
# android       2
# Name: count, dtype: int64

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

# Extracting Values from Strings
laptops["gpu_manufacturer"] = laptops["gpu"].str.split().str[0]
laptops['cpu_manufacturer'] = laptops["cpu"].str.split().str[0]

# Correcting Bad Values - map() method - če vrednost pozabimo postane nan
mapping_os = {
    "macOS": "mac",
    "No OS": None,
    "Windows": "windows",
    "Mac OS": "mac",
    "Linux": "linux",
    "Android": "android",
    "Chrome OS": "chrome_os"
}
laptops["os"] = laptops["os"].map(mapping_os)

# Missing data
laptops.loc[(laptops["os"] == "mac") & laptops["os_version"].isnull(), "os_version"] = "X"

laptops.head(2)
# Out:
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
#
#                                screen                   cpu  ram_gb  \
# 0  IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz       8
# 1                            1440x900  Intel Core i5 1.8GHz       8
#
#                storage                           gpu   os os_version  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  mac          X
# 1  128GB Flash Storage        Intel HD Graphics 6000  mac          X
#
#    weight_kg  price_euros gpu_manufacturer cpu_manufacturer
# 0       1.37      1339.69            Intel            Intel
# 1       1.34       898.94            Intel            Intel

# %% [markdown]
# ## Removing Duplicates

# %%
laptops.duplicated().value_counts()
# Out:
# False    1275
# True       28
# Name: count, dtype: int64

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

# Extracting Values from Strings
laptops["gpu_manufacturer"] = laptops["gpu"].str.split().str[0]
laptops['cpu_manufacturer'] = laptops["cpu"].str.split().str[0]

# Correcting Bad Values - map() method - če vrednost pozabimo postane nan
mapping_os = {
    "macOS": "mac",
    "No OS": None,
    "Windows": "windows",
    "Mac OS": "mac",
    "Linux": "linux",
    "Android": "android",
    "Chrome OS": "chrome_os"
}
laptops["os"] = laptops["os"].map(mapping_os)

# Missing data
laptops.loc[(laptops["os"] == "mac") & laptops["os_version"].isnull(), "os_version"] = "X"

# Removing Duplicates
print(f"Pred odstranitvijo duplikatov: {laptops.shape[0]}")
laptops = laptops.drop_duplicates()
print(f"Po odstranitvi duplikatov: {laptops.shape[0]}")

# Replacing Values
laptops = laptops.replace("MSI", "Micro-Star International")

# Extract the screen resolution from the screen column
resolution = laptops["screen"].str.split(" ").str[-1].str.split("x")
laptops["screen_width_px"] = resolution.str[0].astype("int")
laptops["screen_hight_px"] = resolution.str[1].astype("int")  
# Dropping Columns - screen
laptops = laptops.drop(columns=["screen"])

laptops.head(2)
# Out:
# Pred odstranitvijo duplikatov: 1303
# Po odstranitvi duplikatov: 1275
#   manufacturer   model_name   category  screen_size_inches  \
# 0        Apple  MacBook Pro  Ultrabook                13.3
# 1        Apple  Macbook Air  Ultrabook                13.3
#
#                     cpu  ram_gb              storage  \
# 0  Intel Core i5 2.3GHz       8            128GB SSD
# 1  Intel Core i5 1.8GHz       8  128GB Flash Storage
#
#                             gpu   os os_version  weight_kg  price_euros  \
# 0  Intel Iris Plus Graphics 640  mac          X       1.37      1339.69
# 1        Intel HD Graphics 6000  mac          X       1.34       898.94
#
#   gpu_manufacturer cpu_manufacturer  screen_width_px  screen_hight_px
# 0            Intel            Intel             2560             1600
# 1            Intel            Intel             1440              900

# %% [markdown]
# ## Vaje za analizo

# %% [markdown]
# #### Naloga 1: Kateri je najcenejši laptop (top 5), ki ima scren_size več ali enko 15 inchov ter ima najmanj 8 GB RAMa?

# %%
cols_to_show = ['manufacturer', 'model_name', 'price_euros', 'ram_gb', 'screen_size_inches']

# %%
laptops.loc[(laptops["screen_size_inches"] >= 15) & (laptops["ram_gb"] >= 8), cols_to_show].sort_values(by="price_euros").head(1)
# Out:
#     manufacturer         model_name  price_euros  ram_gb  screen_size_inches
# 783       Lenovo  IdeaPad 110-15IBR        329.0       8                15.6

# %% [markdown]
# #### Naloga 2: Določite razliko v popvrečni ceni za latope s procesorjem Intel in AMD

# %%
intel_mean_price = laptops.loc[laptops["cpu_manufacturer"] == "Intel", "price_euros"].mean()
amd_mean_price = laptops.loc[laptops["cpu_manufacturer"] == "AMD", "price_euros"].mean()
print(f"AMD je v povprečju cenejši za {intel_mean_price - amd_mean_price: .2f}€")
# Out:
# AMD je v povprečju cenejši za  602.74€

# %% [markdown]
# #### Naloga 3: Kateri laptop ima največ RAMa?

# %%
laptops[laptops['ram_gb'] == laptops['ram_gb'].max()]
# Out:
#      manufacturer  model_name category  screen_size_inches  \
# 1066         Asus  ROG G701VO   Gaming                17.3
#
#                               cpu  ram_gb  storage                      gpu  \
# 1066  Intel Core i7 6820HK 2.7GHz      64  1TB SSD  Nvidia GeForce GTX 980
#
#            os os_version  weight_kg  price_euros gpu_manufacturer  \
# 1066  windows         10       3.58       3975.0           Nvidia
#
#      cpu_manufacturer  screen_width_px  screen_hight_px
# 1066            Intel             1920             1080

# %% [markdown]
# ## Regex in Pandas

# %%
def clean_dataframe_columns(column_name: str) -> str:
    column_name = column_name.replace("(", "").replace(")", "")
    column_name = column_name.replace("Operating System", "os")
    return column_name.strip().replace(" ", "_").lower()

laptops = pd.read_csv("data/INPUT_laptops.csv", encoding="Latin-1")
# Cleaning Column Names
laptops.columns = [clean_dataframe_columns(laptop) for laptop in laptops.columns]

# Converting String Columns to Numeric
# Column - screen_size
laptops["screen_size"] = laptops["screen_size"].str.replace('"', "").astype("float")
# Column - ram
laptops["ram"] = laptops["ram"].str.replace("GB", "").astype("int")
# Column - weight
laptops["weight"] = laptops["weight"].str.replace("kg", "").str.replace("s", "").astype("float")
# Column - price_euros
laptops["price_euros"] = laptops["price_euros"].str.replace(",", ".").astype("float")
laptops = laptops.rename(columns={"ram": "ram_gb", "screen_size": "screen_size_inches", "weight": "weight_kg"})

# Extracting Values from Strings
laptops["gpu_manufacturer"] = laptops["gpu"].str.split().str[0]
laptops['cpu_manufacturer'] = laptops["cpu"].str.split().str[0]

# Correcting Bad Values - map() method - če vrednost pozabimo postane nan
mapping_os = {
    "macOS": "mac",
    "No OS": None,
    "Windows": "windows",
    "Mac OS": "mac",
    "Linux": "linux",
    "Android": "android",
    "Chrome OS": "chrome_os"
}
laptops["os"] = laptops["os"].map(mapping_os)

# Missing data
laptops.loc[(laptops["os"] == "mac") & laptops["os_version"].isnull(), "os_version"] = "X"

# Removing Duplicates
print(f"Pred odstranitvijo duplikatov: {laptops.shape[0]}")
laptops = laptops.drop_duplicates()
print(f"Po odstranitvi duplikatov: {laptops.shape[0]}")

# Replacing Values
laptops = laptops.replace("MSI", "Micro-Star International")

# Extract the screen resolution from the screen column
resolution = laptops["screen"].str.split(" ").str[-1].str.split("x")
laptops["screen_width_px"] = resolution.str[0].astype("int")
laptops["screen_hight_px"] = resolution.str[1].astype("int")  
# Dropping Columns - screen
laptops = laptops.drop(columns=["screen"])

# Add CPU speed 
laptops["cpu_speed_ghz"] = laptops["cpu"].str.extract(r".+\s(\d+\.?\d*)GHz").astype("float")

# Parse storage columns
laptops["storage"] = laptops["storage"].str.replace("1TB", "1000GB")
laptops["storage"] = laptops["storage"].str.replace("2TB", "2000GB")
laptops["storage"] = laptops["storage"].str.replace("Hybrid", "HDD")
result = laptops["storage"].str.extract(r"(\d+)GB\sSSD\s?(\+?\s+(\d+)GB\sSSD)*").fillna(0)
laptops["ssd_gb"] = result[0].astype("int") + result[2].astype("int")

result = laptops["storage"].str.extract(r"(\d+)GB\sHDD\s?(\+?\s+(\d+)GB\sHDD)*").fillna(0)
laptops["hdd_gb"] = result[0].astype("int") + result[2].astype("int")

# 532          10      2.000      1299.00           Nvidia            Intel
# 585          10      4.500      2349.00           Nvidia            Intel
# 603          10      4.140      2199.00           Nvidia            Intel
# 752         NaN      2.450       579.00           Nvidia            Intel
# 767          10      2.720      1099.00           Nvidia            Intel
# 901          10      3.580      1279.00           Nvidia            Intel
# 908          10      2.600       789.00           Nvidia            Intel
# 940          10      2.750      1399.00           Nvidia            Intel
# 962          10      2.400      1009.00           Nvidia            Intel
# 977          10      2.300      1799.00           Nvidia            Intel
# 1047         10      3.780      1545.64           Nvidia            Intel
# 1048         10      4.600      2289.99           Nvidia            Intel
# 1061        NaN      4.000       998.00           Nvidia            Intel
# 1068         10      3.210      1329.00           Nvidia            Intel
# 1076         10      2.300       977.00           Nvidia            Intel
# 1081         10      4.600      3240.00           Nvidia            Intel
# 1095         10      2.400       799.00           Nvidia            Intel
# 1097         10      2.600      1599.00           Nvidia            Intel
# 1099         10      4.300      2299.00           Nvidia            Intel
# 1106         10      2.900      1511.19           Nvidia            Intel
# 1109         10      2.590      1339.00           Nvidia            Intel
# 1116         10      4.600      2749.99           Nvidia            Intel
# 1119         10      3.520      1312.49           Nvidia            Intel
# 1138         10      3.780      2399.00           Nvidia            Intel
# 1161         10      1.700      1769.00           Nvidia            Intel
# 1178         10      1.910      2153.37           Nvidia            Intel
# 1184         10      2.180       799.00           Nvidia            Intel
# 1185         10      2.591       909.00           Nvidia            Intel
# 1197         10      4.300      2150.00           Nvidia            Intel
# 1228         10      2.600      1029.00           Nvidia            Intel
# 1238         10      2.300      1169.00           Nvidia            Intel
# 1256         10      4.000      1900.00           Nvidia            Intel
# 1259         10      2.400      1229.00           Nvidia            Intel
# 1265         10      2.600       899.00           Nvidia            Intel
#
#       screen_width_px  screen_hight_px  cpu_speed_ghz
# 228              1920             1080            2.5
# 242              1920             1080            2.7
# 251              1920             1080            2.8
# 302              1600              900            2.5
# 494              1920             1080            2.6
# 532              3840             2160            2.7
# 585              1920             1080            2.7
# 603              1920             1080            2.7
# 752              1366              768            2.3
# 767              3840             2160            2.6
# 901              1920             1080            2.7
# 908              1920             1080            2.3
# 940              1920             1080            2.3
# 962              1920             1080            2.5
# 977              3840             2160            2.7
# 1047             1920             1080            2.7
# 1048             1920             1080            2.6
# 1061             1920             1080            2.6
# 1068             3840             2160            2.6
# 1076             1920             1080            2.3
# 1081             1920             1080            2.7
# 1095             1920             1080            2.5
# 1097             1920             1080            2.6
# 1099             1920             1080            2.6
# 1106             1920             1080            2.6
# 1109             1920             1080            2.6
# 1116             1920             1080            2.7
# 1119             1920             1080            2.6
# 1138             1920             1080            2.7
# 1161             1920             1080            2.6
# 1178             1920             1080            2.6
# 1184             1920             1080            2.6
# 1185             1920             1080            2.6
# 1197             1920             1080            2.6
# 1228             1920             1080            2.6
# 1238             1920             1080            2.6
# 1256             1920             1080            2.6
# 1259             1920             1080            2.6
# 1265             1920             1080            2.6

# %% [markdown]
# ## Izvozimo urejen dataset v CSV

# %%
laptops.to_csv("data/laptops_CLEAN.csv", index=False)
